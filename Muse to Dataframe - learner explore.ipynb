# %%
from google.oauth2 import service_account
import pandas_gbq
import pandas as pd

credentials = service_account.Credentials.from_service_account_info(
{
  "type": "service_account",
  "project_id": "smart-science",
  "private_key_id": "385ab38186b673216cdb3ae0896078eacdcd26db",
  "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
  "client_email": "queries-exports@smart-science.iam.gserviceaccount.com",
  "client_id": "116135261809379363144",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/queries-exports%40smart-science.iam.gserviceaccount.com"
},
)

# %%
combined = pandas_gbq.read_gbq(
    "SELECT * FROM `smart-science.Learners_Questions.Combined_tables_39k`",
    project_id="smart-science", credentials=credentials)

# %%
combined
# Out:
#                 learner question answer                    last_modified  \
# 0      4535845151309824      368   None 2017-06-04 15:56:53.694550+00:00
# 1      4535845151309824      371   None 2017-06-04 15:56:57.464360+00:00
# 2      4535845151309824       38   None 2017-08-31 11:44:55.225370+00:00
# 3      4536217521618944      105   True 2017-01-15 01:09:29.722880+00:00
# 4      4536217521618944      106   True 2017-01-15 01:10:26.626710+00:00
# 5      4536217521618944      108   True 2017-01-15 01:08:42.139380+00:00
# 6      4536217521618944       13   True 2017-01-15 01:08:05.121310+00:00
# 7      4536217521618944       15   True 2017-01-15 01:08:37.129050+00:00
# 8      4536217521618944       18  False 2017-01-15 01:12:11.837940+00:00
# 9      4536217521618944       19   True 2017-01-15 01:13:34.044540+00:00
# 10     4536217521618944       22   True 2017-01-15 01:09:13.026640+00:00
# 11     4536217521618944       22   True 2017-01-15 01:11:47.430450+00:00
# ...

# %%
learner_lst = []
for i in combined.index:
    learner_lst.append(combined.loc[i, 'learner'])

print(len(set(learner_lst)))
learner_lst = set(learner_lst)
# Out:
# 2967

# %%
learner_df = combined[['learner']]

# %%
learner_df = learner_df.drop_duplicates(keep='last')

# %%
learner_df.reset_index(inplace=True, drop=True)

# %%
learner_df
# Out:
#       index           learner
# 0         2  4535845151309824
# 1        92  4536217521618944
# 2        94  4536398325481472
# 3       100  4551846551093248
# 4       106  4554084669456384
# 5       108  4563324725362688
# 6       112  4570824568733696
# 7       115  4576288907984896
# 8       118  4594617454428160
# 9       120  4597232309370880
# 10      123  4611123475120128
# 11      125  4613797645910016
# 12      128  4619529606922240
# 13      134  4623601126866944
# 14      136  4628968502198272
# 15      138  4631671437524992
# 16      140  4631909271339008
# 17      180  4640195836116992
# 18      185  4643024344711168
# 19      188  4643216242507776
# 20      190  4646135276765184
# 21      196  4649037902905344
# 22      297  4649666666823680
# 23      300  4651483148582912
# 24      302  4654768731455488
# 25      304  4657658128760832
# 26      307  4657999083732992
# 27      314  4659795990675456
# 28      316  4664326778519552
# 29      318  4666370654470144
# ...

# %%
learners_df = pandas_gbq.read_gbq(
    "SELECT * FROM `smart-science.Learners_Questions.Learners`",
    project_id="smart-science", credentials=credentials)

# %%
learners_df.shape
# Out:
# (2734, 1)

# %%
learners_df = learners_df.drop_duplicates(keep='last')

# %%
learners_df['learner']
# Out:
# 0       5767494685949952
# 1       5656462332264448
# 2       5630088112504832
# 3       5638203017003008
# 4       5649952705347584
# 5       5741642204053504
# 6       5462642772672512
# 7       5633067678957568
# 8       5180118280437760
# 9       5718264999051264
# 10      6057041550376960
# 11      5720693702393856
# 12      5710246563545088
# 13      4706352450502656
# 14      5743068233859072
# 15      5947893009612800
# 16      5630978613575680
# 17      5468492786565120
# 18      5747175027900416
# 19      5655148575588352
# 20      5754323531202560
# 21      5722522989363200
# 22      5657375784566784
# 23      5688922571014144
# 24      5733848012816384
# 25      5717264808542208
# 26      5685665089978368
# 27      5766862319124480
# 28      5497519786164224
# 29      5734023099842560
#               ...
# 2704    5687375338405888
# 2705    5643255840505856
# 2706    4878616789778432
# 2707    5680697989660672
# 2708    5649748371439616
# 2709    5430897973133312
# ...

# %%
learners_lst = []
for i in learners_df.index:
    learners_lst.append(learners_df.loc[i, 'learner'])

print(len(set(learners_lst)))
learners_lst = set(learners_lst)
# Out:
# 2734

# %%
learners_lst - learner_lst
# Out:
# {5127543854202880, 5145926448447488, 5740395606573056}

# %%
missing = learner_lst - learners_lst

# %%
missing = list(missing)

# %%
count = 0

for i in combined.index:
    if combined.at[i, 'learner'] in missing:
        count += 1
        #print(i)

# %%
count
# Out:
# 9346

# %%
len(missing)
# Out:
# 236
