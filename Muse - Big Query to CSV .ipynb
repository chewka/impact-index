# %%
import json
import pandas as pd
import time
import gcsfs

# %%
from google.cloud import storage
from google.cloud import bigquery
from pathlib import Path
import os

# %%
PROJ_ROOT = Path().resolve().parent
KEYS_DIR = PROJ_ROOT / 'keys' 
keys = KEYS_DIR / 'key-query-export.json'

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = str(keys)

# %%
project = 'smart-science'
dataset_id = 'Learners_Questions'
table_id = 'Combined_tables_39k'
bucket_name = 'muse-data'

# Setup Storage vars
storage_client = storage.Client(project=project)
bucket = storage_client.get_bucket('muse-data')

# Setup BigQuery vars
bq_client = bigquery.Client()
dataset_ref = bq_client.dataset(dataset_id, project=project)
table_ref = dataset_ref.table(table_id)

#destination
destination_uri = "gs://{}/{}".format(bucket_name, "combined_tables_raw.json")
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-63-32671d727706> in <module>
#       6 # Setup Storage vars
#       7 storage_client = storage.Client(project=project)
# ----> 8 bucket = storage_client.get_bucket('muse-data')
#       9
#      10 # Setup BigQuery vars
#
# ~/socos/impact-index/env/lib/python3.7/site-packages/google/cloud/storage/client.py in get_bucket(self, bucket_or_name)
#     276         bucket = self._bucket_arg_to_bucket(bucket_or_name)
#     277
# --> 278         bucket.reload(client=self)
#     279         return bucket
#     280
#
# ~/socos/impact-index/env/lib/python3.7/site-packages/google/cloud/storage/_helpers.py in reload(self, client)
#     128             query_params=query_params,
#     129             headers=self._encryption_headers(),
# --> 130             _target_object=self,
#     131         )
#     132         self._set_properties(api_response)
#
# ~/socos/impact-index/env/lib/python3.7/site-packages/google/cloud/_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object)
#     391
#     392         if not 200 <= response.status_code < 300:
# --> 393             raise exceptions.from_http_response(response)
#     394
#     395         if expect_json and response.content:
#
# Forbidden: 403 GET https://www.googleapis.com/storage/v1/b/muse-data?projection=noAcl: big-query-admin@smart-science.iam.gserviceaccount.com does not have storage.buckets.get access to muse-data.

# %%
query_job_config = bigquery.QueryJobConfig()
query_job_config.write_disposition = 'WRITE_TRUNCATE'
# Set the destination table
original_table_ref = bq_client.dataset(dataset_id).table('New_table')
query_job_config.destination = table_ref

sql = """
    SELECT a.JiveLearner.id as learner, b.message.jive_id as question, a.answer, a.last_modified, a.JiveEnvelope.name, b.message.learner_name, a.tags.tag, a.tags.metatag, c.who, c.text, c.answer_type
    FROM `socos-quickstep-601.museathome.BinaryQuestionAnswer` as a
    JOIN `socos-quickstep-601.museathome.JiveEnvelope` as b ON a.JiveEnvelope.name=b.__key__.name
    JOIN `socos-quickstep-601.museathome.questions` as c ON CAST(b.message.jive_id AS NUMERIC) = c.id
    ORDER BY a.JiveLearner.id, b.message.learner_name, question ASC
"""

# Start the query, passing in the extra configuration.
query_job = bq_client.query(
    sql,
    # Location must match that of the dataset(s) referenced in the query
    # and of the destination table.
    location='US',
    job_config=query_job_config)  # API request - starts the query

query_job.result()  # Waits for the query to finish
print('Query results loaded to table {}'.format(table_ref.path))
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-78-fc32926bc4a3> in <module>
#      21     job_config=query_job_config)  # API request - starts the query
#      22
# ---> 23 query_job.result()  # Waits for the query to finish
#      24 print('Query results loaded to table {}'.format(table_ref.path))
#
# ~/socos/impact-index/env/lib/python3.7/site-packages/google/cloud/bigquery/job.py in result(self, timeout, page_size, retry)
#    2906         """
#    2907         try:
# -> 2908             super(QueryJob, self).result(timeout=timeout)
#    2909
#    2910             # Return an iterator instead of returning the job.
#
# ~/socos/impact-index/env/lib/python3.7/site-packages/google/cloud/bigquery/job.py in result(self, timeout, retry)
#     731             self._begin(retry=retry)
#     732         # TODO: modify PollingFuture so it can pass a retry argument to done().
# --> 733         return super(_AsyncJob, self).result(timeout=timeout)
#     734
#     735     def cancelled(self):
#
# ~/socos/impact-index/env/lib/python3.7/site-packages/google/api_core/future/polling.py in result(self, timeout)
#     125             # pylint: disable=raising-bad-type
#     126             # Pylint doesn't recognize that this is valid in this case.
# --> 127             raise self._exception
#     128
#     129         return self._result
#
# Forbidden: 403 Access Denied: Table socos-quickstep-601:museathome.BinaryQuestionAnswer: User does not have permission to query table socos-quickstep-601:museathome.BinaryQuestionAnswer.
#
# (job ID: 6c3ff9ea-e915-425a-9ad3-f0d1dd5cbf4f)
#
#                                                                                       -----Query Job SQL Follows-----
#
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |
#    1:
#    2:    SELECT a.JiveLearner.id as learner, b.message.jive_id as question, a.answer, a.last_modified, a.JiveEnvelope.name, b.message.learner_name, a.tags.tag, a.tags.metatag, c.who, c.text, c.answer_type
#    3:    FROM `socos-quickstep-601.museathome.BinaryQuestionAnswer` as a
#    4:    JOIN `socos-quickstep-601.museathome.JiveEnvelope` as b ON a.JiveEnvelope.name=b.__key__.name
#    5:    JOIN `socos-quickstep-601.museathome.questions` as c ON CAST(b.message.jive_id AS NUMERIC) = c.id
#    6:    ORDER BY a.JiveLearner.id, b.message.learner_name, question ASC
#     |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |    .    |

# %%
#set job configuration to extract job as JSON files
extract_job_config = bigquery.ExtractJobConfig()
extract_job_config.destination_format = 'NEWLINE_DELIMITED_JSON'
extract_job_config.write_disposition = 'WRITE_TRUNCATE'

# %%
extract_job = bq_client.extract_table(
    table_ref,
    destination_uri,
    # Location must match that of the source table.
    location="US",
    job_config=extract_job_config
)  # API request
extract_job.result()  # Waits for job to complete.

print(
    "Exported {}:{}.{} to {}".format(project, dataset_id, table_id, destination_uri)
)
# Out:
# Exported smart-science:Learners_Questions.Combined_Tables to gs://muse-data/combined_tables_raw.json

# %%
df = pd.read_json(destination_uri, lines=True)

# %%
df
# Out:
#        answer answer_type                   last_modified           learner  \
# 0         NaN      binary   2017-06-04 15:56:53.69455 UTC  4535845151309824
# 1         NaN      binary   2017-06-04 15:56:57.46436 UTC  4535845151309824
# 2         NaN      binary   2017-08-31 11:44:55.22537 UTC  4535845151309824
# 3         1.0      binary   2017-01-15 01:09:13.02664 UTC  4536217521618944
# 4         1.0      binary   2017-01-15 01:11:47.43045 UTC  4536217521618944
# 5         1.0       scale   2017-01-15 01:09:10.63448 UTC  4536217521618944
# 6         1.0       scale   2017-01-15 01:11:49.84119 UTC  4536217521618944
# 7         1.0       scale   2017-01-15 01:08:00.33935 UTC  4536217521618944
# 8         0.0      binary   2017-01-15 01:13:38.63336 UTC  4536217521618944
# 9         1.0       scale   2017-01-15 01:07:52.71889 UTC  4536217521618944
# 10        1.0       scale   2017-01-15 01:18:27.42177 UTC  4536217521618944
# 11        0.0       scale   2017-01-15 01:09:13.02252 UTC  4536217521618944
# 12        1.0       scale    2017-01-15 01:14:31.5425 UTC  4536217521618944
# 13        0.0       scale   2017-01-15 01:11:00.13816 UTC  4536217521618944
# 14        0.0       scale   2017-01-15 01:12:31.62683 UTC  4536217521618944
# 15        1.0       scale   2017-01-15 01:18:11.72885 UTC  4536217521618944
# 5             [yes]  Does {kid_name} complete familiar books, espec...   child
# 6             [yes]           Does {kid_name} enjoy trying new things?   child
# 7             [yes]  Does {kid_name} enjoy creating elaborate prete...   child
# 8              [no]  Are you the first person in your family to gra...  parent
# 9             [yes]         Does {kid_name} usually share with others?   child
# 10            [yes]  For the most part, do you enjoy your daily act...  parent
# 11             [no]  Do you feel like you need to have "all the ans...  parent
# 12            [yes]           Do you have a favorite outdoor activity?  parent
# 13             [no]  In the last week, have you had a hard time bal...  parent
# 14             [no]    In the last month, have you made a new friend?   parent
# 15            [yes]  Would you like to make new friends with people...  parent
# 16             [no]  In the last week, have you noticed {kid_name} ...   child
# 17            [yes]  In the past month, have you been able to recog...  parent
# 18            [yes]  Do you and {kid_name} talk about things {kid_n...   child
# 19             [no]  Do you often complain that you feel like you l...  parent
# 20             [no]  Imagine it’s 20 years in the future and you’re...  parent
# 21             [no]  If you recorded family dinner, would the conve...  parent
# 22            [yes]  Have you and {kid_name} played a game together...   child
# 23            [yes]  Does {kid_name} attend school outside of the h...   child
# 24            [yes]                   Do you work outside of the home?  parent
# 25            [yes]     Do you have reliable childcare for {kid_name}?  parent
# 26            [yes]                   Do you work outside of the home?  parent
# 27            [yes]                   Do you work outside of the home?  parent
# 28       [somewhat]                            Does your spouse smoke?  parent
# 29     [definitely]                            Does your spouse smoke?  parent
# ...             ...                                                ...     ...
# 32657         [yes]                   Do you work outside of the home?  parent
# 32658          [no]  Are there families in your neighborhood that a...  parent
# 32659         [yes]  Are there families in your neighborhood that a...  parent
# 32660  [definitely]  Do you know where the nearest playground is fr...  parent
# 32661          [no]  Does {kid_name} attend school outside of the h...   child
# 32662          [no]     Do you have reliable childcare for {kid_name}?  parent
# 32663         [yes]                 Does your family have health care?  parent
# 32664         [yes]     Do you have reliable childcare for {kid_name}?  parent
# 32665         [yes]                   Do you work outside of the home?  parent
# 32666         [yes]                 Did you graduate from high school?  parent
# 32667         [yes]     Do you have reliable childcare for {kid_name}?  parent
# 32668         [yes]                   Do you work outside of the home?  parent
# 32669         [yes]     Do you have reliable childcare for {kid_name}?  parent
# 32670         [yes]                   Do you work outside of the home?  parent
# 32671         [yes]  Every household is different and I want to lea...  parent
# 32672    [probably]  Active play is key to learning! Do you have a ...  parent
# 32673         [yes]                 Does your family have health care?  parent
# 32674         [yes]  Does {kid_name} attend school outside of the h...   child
# 32675         [yes]     Do you have reliable childcare for {kid_name}?  parent
# 32676         [yes]  Does {kid_name} attend school outside of the h...   child
# 32677         [yes]  Does {kid_name} attend school outside of the h...   child
# 32678         [yes]                   Do you work outside of the home?  parent
# 32679         [yes]     Do you have reliable childcare for {kid_name}?  parent
# 32680         [yes]                   Do you work outside of the home?  parent
# 32681         [yes]     Do you have reliable childcare for {kid_name}?  parent
# 32682         [yes]                   Do you work outside of the home?  parent
# 32683         [yes]  Active play is key to learning! Do you have a ...  parent
# 32684         [yes]     Do you have reliable childcare for {kid_name}?  parent
# 32685         [yes]                   Do you work outside of the home?  parent
# 32686          [no]                                      Do you smoke?  parent
#
# [32687 rows x 11 columns]

# %%
df['metatag'].dtype
# Out:
# dtype('O')

# %%
df.iloc[35, 5]
# Out:
# ['feedback', 'answer']

# %%
count = 0
for i in df.index:
    if 'feedback' in df.iloc[i, 5]:
        count = count + 1
print(count)
# Out:
# 15110

# %%
count = 0
for i in df.index:
    if 'answer' in df.iloc[i, 5]:
        count = count + 1
print(count)
# Out:
# 30929
