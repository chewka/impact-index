# %%
import pandas as pd
import numpy as np
import json

# %%
xls = pd.ExcelFile('/Users/dhyanna/socos/impact-index/data/external/CCDF.xlsx')
df0 = pd.read_excel(xls, 0)

# %%
df0
# Out:
#     CategoryID          TableName  \
# 0            1     Administration
# 1            2         ProgramDev
# 2            3            Appeals
# 3            4    ChangeReporting
# 4            5    Redetermination
# 5            6       Verification
# 6            7        Application
# 7            8      Authorization
# 8            9        CopayExempt
# 9           10        CopayAdjust
# 10          11         CopayAdmin
# 11          12    CopayThresholds
# 12          13        CopayAmount
# 13          14          FamilyDef
# 14          15          IncomeDef
# 15          16     EligThresholds
# 16          17         AssetTests
# 17          18   ProviderPolicies
# 18          19   PriorityPolicies
# 19          20           WaitList
# 20          21            Quality
# 21          22         EarlyLearn
# 22          23            ProfDev
# 23          24      WhoAuthorized
# 24          25       EligCriteria
# 25          27  ReimbursePolicies
# ...

# %%
df10 = pd.read_excel(xls, 10)

# %%
df10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-13aaf5053377> in <module>
# ----> 1 df10
#
# NameError: name 'df10' is not defined
