# %%
import pandas as pd
import numpy as np
from pathlib import Path

PROJ_ROOT = Path().resolve().parent
PRC_DIR = PROJ_ROOT / 'data' / 'processed'

company_df = pd.read_csv(PRC_DIR / 'processed_company_df.csv', index_col=0)
company_df
# Out:
#                                 company_name  \
# 0                                    Resilio
# 1                                 Codementor
# 2                           Smart MultiMedia
# 3                                Evolution 2
# 4               Ultraprise Loan Technologies
# 5                   Workspace Property Trust
# 6                                 86 Repairs
# 7                           Zygo Corporation
# 8                           Steves Ice Cream
# 9                         AKW Analytics Inc.
# 10                                 myWebRoom
# 11                          Medcare Products
# 12                Trusted Translations, Inc.
# 13                         Elevator Controls
# 14                          Reggio Registers
# 15                       BioVigilant Systems
# 16                            Fermata Energy
# 17                               Net Aspects
# 18                      The Athletes Network
# 19                           LG DESIGN STONE
# ...

# %%
# founders = []
# for each in company_df['founders']:
#     if each != np.nan:
#         found = each.replace('[', '').replace(']', '')
#         found = found.split(', ')
#         found = [x.replace("'", '') for x in found]
#         #print(cats)
#         for c in found:
#             if c not in founders:
#                 if c != '':
#                     founders.append(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-55af4afc16bc> in <module>
#       2 for each in company_df['founders']:
#       3     if each != np.nan:
# ----> 4         found = each.replace('[', '').replace(']', '')
#       5         found = found.split(', ')
#       6         found = [x.replace("'", '') for x in found]
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
founders = []
for each in company_df['founders']:
    if each not in founders:
        founders.append(each)

for i in range(0,5):
    print(founders[i])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-035f7525bff6> in <module>
#       1 founders = []
#       2 for each in company_df['founders']:
# ----> 3     if each not in founders:
#       4         founders.append(each)
#       5
#
# KeyboardInterrupt:

# %%
founders = []
for i in range(0,10):
    print(company_df.at[i, 'founders'])
    if company_df.at[i, 'founders'] == np.nan:
        pass
    else:
        new = (company_df.at[i, 'founders'])
        founders = founders.append(new)
# Out:
# ['Anders Søndergaard', 'Thomas Scherning', 'Jette Wied Hatting', 'Helga Halkjær']
# ['Weiting Liu']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-39df6492880d> in <module>
#       6     else:
#       7         new = (company_df.at[i, 'founders'])
# ----> 8         founders = founders.append(new)
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
for i in range(0,10):
    print(company_df.at[i, 'founders'])
# Out:
# ['Anders Søndergaard', 'Thomas Scherning', 'Jette Wied Hatting', 'Helga Halkjær']
# ['Weiting Liu']
# nan
# ['Konrad Kopczynski', 'Alika Graham']
# nan
# ['Roger Thomas', 'Leo Nolan', 'Thomas A. Rizk']
# ['Daniel Estrada', 'Joe Gallagher']
# ['Paul Forman', 'Carl Zanoni', 'Sol Laufer']
# nan
# nan

# %%
for i in range(0, 1):
    for 
    print(company_df.at[i, 'founders'])
    founders.append()
# Out:
# ['Anders Søndergaard', 'Thomas Scherning', 'Jette Wied Hatting', 'Helga Halkjær']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-9b8bd8165f9c> in <module>
#       1 for i in range(0, 1):
#       2     print(company_df.at[i, 'founders'])
# ----> 3     founders.append()
#
# AttributeError: 'NoneType' object has no attribute 'append'
