# %%
# This example uses Python Requests library http://docs.python-requests.org/en/master/
import requests
import json

# Request Parameters
store = "android"       # Could be either "android" or "itunes".
country_code = "US"     # Two letter country code.
date = "2019-09-03"     # Date in YYYY-MM-DD format.

req_params = {"date": date,
              "country": country_code}

# Auth Parameters
username = "6989392c7d00f43e336c5ae80985c75cb6c5bb36"  # Replace {API_KEY} with your own API key.
password = "X"          # Password can be anything.

# Request URL
url = "https://api.appmonsta.com/v1/stores/%s/details.json" % store

# This header turns on compression to reduce the bandwidth usage and transfer time.
headers = {'Accept-Encoding': 'deflate, gzip'}

# Python Main Code Sample
response = requests.get(url,
                        auth=(username, password),
                        params=req_params,
                        headers=headers,
                        stream=True)

print (response.status_code)
for line in response.iter_lines():
  # Load json object and print it out
  json_record = json.loads(line)
  print(json_record)
# Out:
# 200
# {'content_rating': 'Everyone', 'app_name': 'Adventures1', 'content_rating_info': '', 'publisher_id_num': '4959907358435139667', 'requires_os': '5.1 and up', 'related': {'related_apps': ['com.facebook.orca', 'com.kwalee.gunpuzzle', 'com.playstrom.onpipe', 'com.whatsapp', 'com.snapchat.android', 'com.instagram.android', 'com.netflix.mediaclient', 'com.zhiliaoapp.musically', 'com.facebook.katana', 'com.roblox.client', 'scratch.lucky.money.free.real.big.win', 'com.squareup.cash', 'com.amanotes.beathopper', 'com.samsung.android.app.notes', 'com.amanotes.pamadancingroad', 'com.amazon.avod.thirdpartyclient', 'com.nianticlabs.pokemongo', 'com.mgc.runnergame', 'com.agminstruments.drumpadmachine', 'io.faceapp', 'com.pinterest', 'com.playrix.homescapes', 'com.kiloo.subwaysurf', 'com.abtnprojects.ambatana', 'com.facebook.mlite', 'com.waze', 'com.paypal.android.p2pmobile', 'com.creditkarma.mobile', 'io.voodoo.crowdcity', 'com.sonic.sonicdrivein'], 'more_from_developer': ['com.amratta.mysteryman', 'com.wapps.starsball', 'com.amratta.oudhtheadventurer', 'com.amratta.manbarriers', 'com.ESHRAKH.CrazyCar', 'com.fruit.jam']}, 'video_urls': [], 'file_size': '28M', 'publisher_name': 'ESHRAKH', 'id': 'com.badventr.gqsd', 'price_currency': 'USD', 'genres': ['Adventure'], 'app_type': 'GAME', 'icon_url': 'https://lh3.googleusercontent.com/KaV1nIiVk0MB-DmNjIuhz70L2NNFwGFRenDvsnvr_VhMiw599L1dqxK2D_GJI4AmGg', 'interactive_elements': 'Shares Location, Digital Purchases', 'version': '1.0', 'publisher_url': 'http://eshrakh.com/', 'whats_new': 'The first version of the adventurer', 'publisher_id': 'ESHRAKH', 'price': 'Free', 'screenshot_urls': ['https://lh3.googleusercontent.com/PXoPUH-j5FKnIC3SdmV0jF-0j0IY7j9s3PHhrZE1zqf8p5dCgx68yz-Stiy4syIy9Ew', 'https://lh3.googleusercontent.com/MRzOfIQjKNyYSjX0RG5k7NYqxLN4OBqh5vJ5qsAjaJFqb1-GIKZEx7B3__luswyrjW8', 'https://lh3.googleusercontent.com/OIM5v2xNmKHbA7dJtUWq6cXnNkJet9_xU-pxxZM9-ARo9nDSJOiM0I09Zf6-B7oYEuM', 'https://lh3.googleusercontent.com/SThcxyJnf19EsZubi4rcMr9izT-6XCck0twXR6M7Uy_CRCQuBLW46r2yeNx72f5kvOoB', 'https://lh3.googleusercontent.com/ezDSpMrEBFgjlZCGyUVCjn5DW4u71u1Wt0JxkwONCFphrPqdN-HwIGzXJ9AkLiBL_Q', 'https://lh3.googleusercontent.com/rC5Zui_MnxI_PljK9R7EYdaDxRnxfqrUFiKnI9pjSg1G0rvumkfGaQ6FHDxCjGyx4p8'], 'status': 'updated', 'publisher_email': 'amratta2610@gmail.com', 'description': 'Adventure game is a game that develops thinking skills to reach the goal<br>It is based on multiple stages in which the adventurer faces some difficulties to reach his goal and through which he encounters difficulties and risks<br>Be careful until you reach your purpose and goal', 'price_value': 0.0, 'all_rating': 0.0, 'store_url': 'https://play.google.com/store/apps/details?id=com.badventr.gqsd', 'downloads': '0+', 'publisher_address': '', 'status_unix_timestamp': 1542747307, 'genre': 'Adventure', 'bundle_id': 'com.badventr.gqsd', 'genre_ids': ['GAME_ADVENTURE'], 'iap_price_range': '', 'release_date': '2018-11-20', 'all_rating_count': 0, 'permissions': ['full network access', 'view network connections'], 'status_date': 'November 20, 2018', 'genre_id': 'GAME_ADVENTURE'}
# {'content_rating': 'Everyone', 'app_name': 'JFP', 'top_developer': False, 'publisher_id_num': '7271827043070426194', 'requires_os': '2.3.3 and up', 'related': {'related_apps': ['com.facebook.mlite', 'pampam.ibf2', 'com.facebook.orca', 'com.azurgames.stackball', 'com.mgc.runnergame', 'com.geishatokyo.trafficrun', 'com.snapchat.android', 'com.lime.video.player', 'com.whatsapp', 'com.instagram.android', 'com.amanotes.beathopper', 'com.housepaint.game', 'com.netflix.mediaclient', 'com.outfit7.herodash', 'io.voodoo.crowdcity', 'com.roblox.client', 'com.zhiliaoapp.musically', 'com.colorup.game', 'com.spotify.music', 'com.kwalee.jetpackjump', 'com.clean.road', 'com.levelzed.waterjump', 'com.habby.archero', 'com.h8games.blocksbuster', 'com.abtnprojects.ambatana', 'com.playgendary.pinatamasters', 'com.venmo', 'com.colorhole.game', 'jp.pokemon.pokemonscrambleSP', 'com.amanotes.pamadancingroad'], 'more_from_developer': ['com.liquidlemon.satadvisor', 'com.liquidlemon.autovizz', 'com.liquidlemon.phvizz']}, 'video_urls': [], 'file_size': '922k', 'publisher_name': 'Liquid Lemon Limited', 'id': 'co.uk.sqjconsultants.android', 'price_currency': 'USD', 'genres': ['Photography'], 'app_type': 'APPLICATION', 'icon_url': 'https://lh3.googleusercontent.com/RcctFyjlZMsB8DFpe6m5LsHOVdt8CBkEJ_GJWrNHCM6vvY_-pkZUkw2V6x3QTTkN8Vg', 'content_rating_info': '', 'interactive_elements': '', 'version': '1.0', 'publisher_url': 'http://www.liquidlemon.com', 'whats_new': '', 'publisher_id': 'Liquid Lemon Limited', 'price': 'Free', 'screenshot_urls': ['https://lh3.googleusercontent.com/Drj5SYml30z9q1IV30yJffwjQxBmLsqeGeCdSxoMvn5Ye369DTrixQODkJOjVC9r3cE', 'https://lh3.googleusercontent.com/2y_60rz61-Sgtlaww-DZgydgSunopxcO8axaH8dw4RIBaL7UOei0y_iFVj68XbAV9Q', 'https://lh3.googleusercontent.com/XWDBduZq8YI2VavSSdA9AQeH19_WfZIN4Kcilvw49WEbIyQ1OhBEeJ52eHv5zwl03A', 'https://lh3.googleusercontent.com/b4SLRykcEPqo9kteGipQHIIHRGxqZZmac28sYKCo4FtwE8v1Y1ZayquN3l8G0zsFAHg', 'https://lh3.googleusercontent.com/MXPiJKaEllUDruoMvCTES7TVp329cRHlV374DgAV4v9AxnYp1Y5D0GtzQjChA0-bQg', 'https://lh3.googleusercontent.com/ELGveTksqVsjHoetfpRFx6ScGTVWB-G_1QO3A820snOnEcAvKPBi3RkJ1dcgS4mCvKQ'], 'status': 'updated', 'publisher_email': 'stephenqjenkins@googlemail.com', 'description': 'An application that highlights and promotes the work of Jenkins Fine Prints, a Bristol based photographic company.<br>The application allows you to browse through our image catalogue giving you the option to save as a favourite or order directly from Jenkins Fine Prints.<br>The application has a recommendations section that is periodically updated by Jenkins Fine Prints and contains a list of our diary that gives information on the location of our sales teams.', 'price_value': 0.0, 'all_rating': 0.0, 'store_url': 'https://play.google.com/store/apps/details?id=co.uk.sqjconsultants.android', 'downloads': '10+', 'publisher_address': 'Cambridge, Cambridgeshire', 'status_unix_timestamp': 1332963062, 'genre': 'Photography', 'bundle_id': 'co.uk.sqjconsultants.android', 'genre_ids': ['PHOTOGRAPHY'], 'iap_price_range': '', 'all_histogram': {'1': 0, '3': 0, '2': 0, '5': 2, '4': 0}, 'release_date': '2012-03-28', 'all_rating_count': 0, 'permissions': ['view network connections', 'full network access', 'set wallpaper', 'change network connectivity', 'modify or delete the contents of your USB storage', 'read the contents of your USB storage', 'view Wi-Fi connections'], 'status_date': 'March 28, 2012', 'genre_id': 'PHOTOGRAPHY'}
# {'content_rating': 'Everyone', 'app_name': 'The Hills Swim & Tennis Club', 'content_rating_info': '', 'publisher_id_num': '4838224152832929224', 'requires_os': '5.0 and up', 'related': {'related_apps': ['com.amazon.mShop.android.shopping', 'com.hulu.plus', 'com.lightricks.pixaloop', 'com.ubercab', 'com.walmart.android', 'com.enflick.android.TextNow', 'com.playrix.gardenscapes', 'com.neonplay.casualrollersplat2', 'paint.by.number.pixel.art.coloring.drawing.puzzle', 'com.azurgames.stackball', 'com.mgc.runnergame', 'com.amanotes.beathopper', 'com.geishatokyo.trafficrun', 'com.netflix.mediaclient', 'com.instagram.android', 'com.whatsapp', 'io.voodoo.crowdcity', 'com.clean.road', 'com.playgendary.ktb2', 'com.tubitv', 'io.voodoo.holeio', 'com.particlenews.newsbreak', 'com.colorhole.game', 'com.housepaint.game', 'com.outfit7.herodash', 'com.playrix.township', 'com.h8games.blocksbuster', 'com.colorup.game', 'com.kiloo.subwaysurf', 'com.venmo'], 'more_from_developer': ['com.clubautomation.northwest.community', 'com.clubautomation.atlantic.coast', 'com.clubautomation.napa.healthquest', 'com.clubautomation.
# {'content_rating': 'Everyone', 'app_name': 'Water Blade', 'content_rating_info': 'Mild Fantasy Violence', 'publisher_id_num': '4900671669010249970', 'requires_os': '2.3.3 and up', 'related': {'related_apps': ['com.playrix.homescapes', 'com.contextlogic.wish', 'com.classdojo.android', 'com.spotify.music', 'com.playrix.township', 'com.squareup.cash', 'com.dd.doordash', 'com.walmart.android', 'com.amazon.mShop.android.shopping', 'com.bydeluxe.d3.android.program.starz', 'com.pandora.android', 'com.facebook.katana', 'com.ubercab', 'com.youmusic.magictiles', 'com.amazon.avod.thirdpartyclient', 'com.rovio.baba', 'com.particlenews.newsbreak', 'com.hulu.plus', 'com.venmo', 'com.enflick.android.TextNow', 'com.paypal.android.p2pmobile', 'com.microsoft.office.outlook', 'com.pixel.art.coloring.color.number', 'com.kiloo.subwaysurf', 'com.agminstruments.drumpadmachine', 'com.peoplefun.wordcross', 'com.abtnprojects.ambatana', 'com.miniclip.eightballpool', 'com.waze', 'com.ebay.mobile'], 'more_from_developer': ['com.karaokulta.trumpealo', 'com.karaokulta.PetCityBallons', 'com.karaokulta.kommUK', 'com.karaokulta.lalosalvalaciudad', 'com.karaokulta.ivBack', 'com.karaokulta.petcitymaniafree', 'com.karaokulta.kibo', 'com.karaokulta.AVC', 'com.karaokulta.CVRBienesRaices', 'com.karaokulta.ekardegas', 'com.karaokulta.evoluciona', 'com.karaokulta.flonkymotocross', 'com.karaokulta.FrutiVeges', 'com.karaokulta.poshone', 'com.karaokulta.kommerce', 'com.karaokulta.paperbrawlers1', 'com.karaokulta.futtap', 'com.karaokulta.beerushfree', 'com.karaokulta.beerushfull', 'com.karaokulta.darkrushfree', 'com.karaokulta.darkrushfull', 'com.karaokulta.petcitymaniafull', 'com.karaokulta.dragoncrushfull', 'com.karaokulta.dragoncitycrushfree', 'com.karaokulta.antitabaquismo', 'com.karaokulta.holykingdomClash', 'com.karaokulta.chimichangaFull', 'com.karaokulta.alienfamilyfull', 'com.karaokulta.rox', 'com.nextdiaz.oxen.cotizadorapp', 'com.becaggghei.bahbbecaggghei', 'com.karaokulta.soulgate', 'com.karaokulta.holykingdomclashfree', 'air.salvaPollito', 'com.gamexico.dragnalienpro', 'com.karaokulta.fenrir', 'com.karaokulta.staradventure', 'com.karaokulta.shadowcitydash', 'com.karaokulta.texaszombie', 'com.karaokulta.balloonworldadventure', 'com.karaokulta.fundamenttowaterbladeevolution', 'com.karaokulta.mechababe', 'com.gamexico.dragnalien', 'com.karaokulta.paperbrawlers', 'com.karaokulta.retorusia', 'com.karaokulta.plataformako', 'com.karaokulta.InstitutoTepeyac', 'com.Karaokulta.MiCandidato', 'com.karaokulta.downhillslide', 'com.karaokulta.dragoncitycrush', 'com.karaokulta.billbowmotocross', 'com.karaokulta.flightout', 'com.Karaokulta.AtenaAR', 'com.larvaKO.BRIO', 'com.kommerce.freebeauty', 'com.karaokulta.pcmstickerpack', 'com.kommerce.daymarket']}, 'video_urls': [], 'file_size': '26M', 'publisher_name': 'KaraOKulta.com', 'id': 'com.karaokulta.fundamentofull', 'price_currency': 'USD', 'genres': ['Arcade'], 'app_type': 'GAME', 'icon_url': 'https://lh3.googleusercontent.com/O5tW6D9nDjQNbYCixPrfFQIGaaBAX215EtFCdVx5WiYF57-xWqUw13hMKo8e3l_yU6U', 'interactive_elements': '', 'version': '1.0', 'publisher_url': 'http://www.karaokulta.com', 'whats_new': '', 'publisher_id': 'KaraOKulta.com', 'price': '$0.99', 'screenshot_urls': ['https://lh3.googleusercontent.com/eLmQAtxy-ToGNcXDacope_s3uUnVVVwu7RLbwvlQOs9NwQnl-3b9liEgsNn0EisUf0dx', 'https://lh3.googleusercontent.com/x9o7unusf_hpFGyvhIxhq37VHA5PTlwrmhMRJ_nm9wpc2bYdSCUssiVWbyGkFDjx4A', 'https://lh3.googleusercontent.com/6TX4f5FVFxmBvI3EBND4gj7ixqQ36j0bBJupZqV1p5F8igVeUlvztjSiMA1p6v49Tg', 'https://lh3.googleusercontent.com/wXe5xOrop9THv41GG5WWZy-iZgUnMs5tQ3POMxkNL5-w1V3GfB48J6WRVn_cqVSUevU'], 'status': 'updated', 'publisher_email': 'hello@karaokulta.com', 'description': 'The depths of the ocean are still a place full of mysteries and unknown creatures. There are those who affirm that the most rare fish species inhabit ecosystems hidden by darkness.<br><br>Experience life as a creature from the bottom of the sea in a test of extreme s ...
# {'content_rating': 'Teen', 'app_name': 'Yle News English Radio Nettiradio App FI Free', 'content_rating_info': 'Language', 'publisher_id_num': '6133953414268699791', 'requires_os': '4.0 and up', 'related': {'related_apps': ['com.snapchat.android', 'com.remind101', 'com.instagram.android', 'com.playrix.homescapes', 'com.whatsapp', 'com.roblox.client', 'com.playrix.gardenscapes', 'com.classdojo.android', 'com.spotify.music', 'com.tubitv', 'com.amanotes.beathopper', 'com.playrix.township', 'com.bydeluxe.d3.android.program.starz', 'com.rovio.baba', 'com.venmo', 'me.lyft.android', 'com.mgc.runnergame', 'com.paypal.android.p2pmobile', 'com.microsoft.office.outlook', 'com.pinterest', 'com.outfit7.mytalkingtom2', 'com.pixel.art.coloring.color.number', 'com.agminstruments.drumpadmachine', 'com.peoplefun.wordcross', 'com.abtnprojects.ambatana', 'io.voodoo.holeio', 'com.miniclip.eightballpool', 'io.voodoo.crowdcity', 'com.waze', 'com.ebay.mobile'], 'more_from_developer': ['com.exlivinapps.nprnewsradioappliveusa', 'com.exlivinapps.christmasfmradioappireland', 'com.exlivinapps.southernrockradioappde', 'com.exlivinapps.ardmediathekappkostenlosradiofmde', 'com.exlivinapps.tippfmappradioireland', 'com.exlivinapps.raidionalifeappfm', 'com.exlivinapps.wdrhorspielappradiofmde', 'com.exlivinapps.rs2radio943appfmde', 'com.exlivinapps.vibesfm938radioappuk', 'com.exlivinapps.antennebayernoldiesbutgoldiesradioapp', 'com.exlivinapps.astateoftranceradioappde', 'com.exlivinapps.clarefmappradioireland', 'com.exlivinapps.alpenradiovolksmusikappde', 'com.exlivinapps.energydigitalradioappde', 'com.exlivinapps.radioenergysachsenappde', 'com.exlivinapps.radiopaloma100schlagerappde', 'com.exlivinapps.b5aktuellradioappde', 'com.exlivinapps.midwestradioirelandappfm', 'com.exlivinapps.classichits4fmradiosapp', 'com.exlivinapps.radio901monchengladbachappfm', 'com.exlivinapps.premierleagueradioresultslivesoccerukonline', 'com.exlivinapps.ndr903hamburgappradiode', 'com.exlivinapps.f
', 'com.v4.mahmoud.newtebbadeel', 'com.v4.mahmoud.bashra', 'com.alabdelaziz.alborglaboratories_testlist', 'com.goldencode.herbal', 'com.buidroid.firstaidkit', 'com.betterway.makateasabr.al_sabr_sawti', 'com.atlasdata.wasaya_rasoul_allah', 'com.amsy.f_athkar', 'com.betterway.issaafate.dalil_isaaf_wa_tawari', 'com.betterway.rokiabayt.roqya_tathir_al_manzel', 'ae.appfreeislamic.AlRoqiaMp3'], 'more_from_developer': ['com.marvelstudio.sabahimages', 'com.marvelstudio.fatburn', 'com.marvelstudio.selfconfedance', 'com.marvelstudio.alternativemedicine', 'com.marvelstudio.eidadhacards', 'com.marvelstudio.goldenletterimages', 'com.marvelstudio.imagebaby', 'com.marvelstudio.goldennamep2', 'com.marvelstudio.goldennamep1', 'com.marvelstudio.flowersimages', 'com.marvelstudio.asahbyjokes', 'com.marvelstudio.fieryletterimgs', 'com.marvelstudio.eyesmakupimages', 'com.marvelstudio.whatsappimg', 'com.marvelstudio.lettersphotos', 'com.marvelstudio.hekamphotos', 'com.marvelstudio.doaaphotos2', 'com.marvelstudio.doaaphotos', 'com.marvelstudio.loveimages', 'com.marvelstudio.modhekacomments', 'com.marvelstudio.nameseidahlap1', 'com.marvelstudio.eidmsg', 'com.marvelstudio.strongmemory', 'com.marvelstudio.nameseidahlap2', 'com.marvelstudio.nakeshhenaa', 'com.marvelstudio.cheesecakes', 'com.marvelstudio.dietfoods', 'com.marvelstudio.honeysweets', 'com.marvelstudio.highheelshoes', 'com.marvelstudio.lipsticks', 'com.marvelstudio.hairdye', 'com.marvelstudio.earpiercing2', 'com.marvelstudio.aktoboilayha', 'com.marvelstudio.girlsaccessories', 'com.marvelstudio.earpiercing', 'com.marvelstudio.ahbkwakfaa', 'com.marvelstudio.muhjabatt2', 'com.marvelstudio.nailcoloring', 'com.marvelstudio.indiansari', 'com.marvelstudio.weddingdresses', 'com.marvelstudio.koreanhairstyles', 'com.marvelstudio.heartssayings', 'com.marvelstudio.mahshywasfat', 'com.marvelstudio.sisterpics', 'com.marvelstudio.brotherpics', 'com.marvelstudio.motherpics', 'com.marvelstudio.fatherpics', 'com.marvelstudio.kunafawasfat', 'com.marvelstudio.pastawasfat', 'com.marvelstudio.housekeeping', 'com.marvelstudio.ashqahapics', 'com.marvelstudio.capitalscountry', 'com.marvelstudio.facecarewasfat', 'com.marvelstudio.bagelwasfat', 'com.marvelstudio.cakewasfat', 'com.marvelstudio.inventionsw', 'com.marvelstudio.muhjabatturkyp1', 'com.marvelstudio.coldsweetwasfat', 'com.marvelstudio.shawermawasfat', 'com.marvelstudio.easternsweetwasfat', 'com.marvelstudio.pizzawasfat', 'com.marvelstudio.chickenwasfat', 'com.marvelstudio.seafoodwasfat', 'com.marvelstudio.pregnancydiseases', 'com.marvelstudio.moajanatwasfat', 'com.marvelstudio.hairoils', 'com.marvelstudio.hairintensifywasfat', 'com.marvelstudio.skincarewasfat', 'com.marvelstudio.haircarewasfat', 'com.marvelstudio.teethwhiteningwasfat', 'com.marvelstudio.saladswasfat', 'com.marvelstudio.acnetreatmentwasfat', 'com.marvelstudio.losefatswasfat2', 'com.marvelstudio.increaseweightwasfat', 'com.marvelstudio.bodyoilswasfat', 'com.marvelstudio.typeoffetusw', 'com.marvelstudio.oilyskincarewasfat', 'com.marvelstudio.nailcarewasfat', 'com.marvelstudio.juiceswasfat', 'com.marvelstudio.potatowasfat', 'com.marvelstudio.sandwichwasfat', 'com.marvelstudio.meatswasfat', 'com.marvelstudio.adorationrulesw', 'com.marvelstudio.lovepoemsw', 'com.marvelstudio.bellyex ...
# {'content_rating': 'Teen', 'app_name': 'test application', 'content_rating_info': '', 'publisher_id_num': '6552110724162913233', 'requires_os': '6.0 and up', 'related': {'related_apps': ['jp.pokemon.pokemonscrambleSP', 'com.amanotes.pamadancingroad', 'io.voodoo.paper2', 'com.nianticlabs.hpwu.prod', 'com.cassette.aquapark', 'com.train.taxi', 'pampam.ibf2', 'com.snapchat.android', 'com.netflix.mediaclient', 'com.amanotes.beathopper', 'com.instagram.android', 'com.whatsapp', 'com.geishatokyo.trafficrun', 'com.azurgames.stackball', 'com.roblox.client', 'io.voodoo.crowdcity', 'com.olo.dairyqueen.production', 'com.lightricks.pixaloop', 'com.tubitv', 'com.housepaint.game', 'paint.by.number.pixel.art.coloring.drawing.puzzle', 'io.voodoo.holeio', 'tv.pluto.android', 'com.venmo', 'com.crazylabs.pull.the.strings', 'com.kiloo.subwaysurf', 'com.matchington.mansion', 'me.lyft.android', 'com.mcdonalds.app', 'com.pinterest'], 'more_from_developer': ['com.it.velvettspa', 'com.it.velvettaspa']}, 'video_urls': [], 'file_size': '1.1M', 'publisher_name': 'Czars India', 'id': 'com.it.testwebview', 'price_currency': 'USD', 'genres': ['Shopping'], 'app_type': 'APPLICATION', 'icon_url': 'https://lh3.googleusercontent.com/4ms3VkEYhvLpxzzChAHpLyC0rGZIvO2TqZT0ruDkViRj9BZdyOxVplT8iRAOt75LTG0', 'interactive_elements': 'Users Interact', 'version': '1.0', 'publisher_url': 'http://czarsit.co.in', 'whats_new': '', 'publisher_id': 'Czars India', 'price': 'Free', 'screenshot_urls': ['https://lh3.googleusercontent.com/nFJ12IBAX6dL9A1B3aEA9ixiobZO2el7Od9Qs6ELJckLh0RB9WT_lvAGKYad5-AUy-4', 'https://lh3.googleusercontent.com/Jq1hK9f2RRJXTm2Dm3tAx9teZkFJD9h5BTcmNgqfI3Te_6cYCByR10ptl_IeQ-1GlWU'], 'status': 'updated', 'publisher_email': 'm.tauseef65@gmail.com', 'description': 'this app for testing purposes of webview version. <br>I am testing for native app<br>this app for testing purposes of webview version. <br>I am testing for native app<br>this app for testing purposes of webview version. <br>I am testing for native app<br>this app for testing purposes of webview version. <br>I am testing for native app', 'price_value': 0.0, 'all_rating': 0.0, 'store_url': 'https://play.google.com/store/apps/details?id=com.it.testwebview', 'downloads': '5+', 'publisher_address': '', 'status_unix_timestamp': 1550465155, 'genre': 'Shopping', 'bundle_id': 'com.it.testwebview', 'genre_ids': ['SHOPPING'], 'iap_price_range': '', 'all_histogram': {'1': 0, '3': 0, '2': 0, '5': 1, '4': 0}, 'release_date': '2019-02-18', 'all_rating_count': 0, 'permissions': ['full network access'], 'status_date': 'February 18, 2019', 'genre_id': 'SHOPPING'}
.weatherorlando', 'com.hikersbay.weatherukraine', 'com.hikersbay.weathersouthafrica', 'com.hikersbay.weatherdenmark', 'com.hikersbay.weatherchile', 'com.hikersbay.weatherireland', 'com.hikersbay.weatherasia', 'com.hikersbay.mapsofflinenorthamerica', 'com.hikersbay.mapsofflinepoland', 'com.hikersbay.mapsofflinedenmark', 'com.hikersbay.mapsofflinefinland', 'com.hikersbay.mapsofflinenetherlands', 'com.hikersbay.mapsofflinesweden', 'com.hikersbay.mapsofflinebavarianalps', 'com.hikersbay.mapsofflineasia', 'com.hikersbay.mapsofflineeurope', 'com.hikersbay.mapsofflineargentina', 'com.hikersbay.mapsofflinebrazil', 'com.hikersbay.mapsofflineqatar', 'com.hikersbay.mapsofflinelima', 'com.hikersbay.mapsofflinepakistan', 'com.hikersbay.mapsofflinerussia', 'com.hikersbay.mapsofflinesydney', 'com.hikersbay.mapsofflineriyadh', 'com.hikersbay.mapsofflineriodejaneiro', 'com.hikersbay.mapsofflinemontreal', 'com.hikersbay.mapsofflinemelbourne', 'com.hikersbay.mapsofflinelagos', 'com.hikersbay.mapsofflineperu', 'com.hikersbay.mapsofflinehanoi', 'com.hikersbay.mapsofflinekarachi', 'com.hikersbay.mapsofflinehochiminh', 'com.hikersbay.mapsofflinecapetown', 'com.hikersbay.mapsofflinecairo', 'com.hikersbay.mapsofflinebeijing', 'com.hikersbay.mapsofflineseoul', 'com.hikersbay.mapsofflinenice', 'com.hikersbay.mapsofflinemacau', 'com.hikersbay.mapsofflineportugal', 'com.hikersbay.mapsofflinemilan', 'com.hikersbay.mapsofflineba ...
# {'content_rating': 'Everyone', 'app_name': 'TTerm', 'top_developer': False, 'publisher_id_num': '7007733488655910424', 'requires_os': '4.4 and up', 'related': {'related_apps': ['com.appsvalley.bluetooth.arduinocontroller', 'it.Ettore.raspcontrollerProKey', 'no.gar.glink5250', 'com.inspiredandroid.linuxcommandbibliotheca', 'com.obddriver.free', 'de.kai_morich.serial_usb_terminal', 'ru.iiec.pydroid2', 'org.kde.kdeconnect_tp', 'com.cea.raspmanager', 'com.shenyaocn.android.BlueSPP', 'de.eidottermihi.raspicheck', 'uk.co.knowles_online.raspberryssh', 'ru.meefik.busybox', 'com.cgutman.androidremotedebugger', 'yarolegovich.materialterminal', 'com.sonelli.juicessh', 'com.server.auditor.ssh.client', 'com.thiyagaraaj.unixcommands', 'sk.vx.connectbot', 'de.kai_morich.serial_wifi_terminal', 'it.Ettore.raspcontroller', 'org.ovirt.mobile.movirt', 'com.ddm.qute', 'tech.ula', 'com.n0n3m4.droidpascal', 'de.hp.terminalshortcut', 'de.kai_morich.serial_bluetooth_terminal', 'com.sweinc.powershell', 'ru.chipenable.avrcalculator.free', 'nextprototypes.BTSerialController'], 'more_from_developer': []}, 'video_urls': [], 'file_size': '836k', 'publisher_name': 'ThH', 'id': 'de.t2h.tterm', 'price_currency': 'USD', 'genres': ['Tools'], 'app_type': 'APPLICATION', 'icon_url': 'https://lh3.googleusercontent.com/kDKo7VSinM8_O2EFRAYFSlMZ0ZJS5vBXU5_EOGEXSc7L_Kn-SOAGCvttmvOm_iBL4JM', 'content_rating_info': '', 'interactive_elements': '', 'version': '0.2.0 (beta)', 'publisher_url': '', 'whats_new': 'Added an extra button for the Context Menu.\nExpanded the help section considerably.\nThe setting Default to UTF-8 is now checked by default. This is necessary to get non-ASCII characters like "á ä æ i š б".\nFixed Bug 005, Alt-Gr does not work on hardware keyboards.', 'publisher_id': 'ThH', 'price': 'Free', 'screenshot_urls': ['https://lh3.googleusercontent.com/L9gQ_TU74AkQc8Cyspy2ybLgXlcX4mGfdrIBYwCOghpeSXq3-g__onY-NiBkR7hO2A', 'https://lh3.googleusercontent.com/Q2vOaC1DFxEyTcE0WXvtHZ8p7nUvWUC7O8tH-WGueaQ81G_vnAhsJW7olCdtg2sZ7A'], 'status': 'updated', 'publisher_email': 'thorbj.hansen@gmail.com', 'description': 'TTerm is a terminal emulator for Android with improved support for on-screen keyboards (also called virtual keyboards, soft keyboards or IMEs). It has extra keys for `Ctrl´, `Tab´, `Esc´ and the cursor keys so that you can continue using your favorite on-screen keyboard even if it lacks those keys.<br><br>TTerm is based on Jack Palevich\'s "Terminal Emulator for Android".<br><br>TTerm is still in beta, so remember to save your work early and often.<br><br>For more information, consult<br>  http://t2h.de/android/tterm/1-index.xhtml', 'price_value': 0.0, 'all_rating': 4.5, 'store_url': 'https://play.google.com/store/apps/details?id=de.t2h.tterm', 'downloads': '10,000+', 'publisher_address': '', 'status_unix_timestamp': 1516614288, 'genre': 'Tools', 'bundle_id': 'de.t2h.tterm', 'genre_ids': ['TOOLS'], 'iap_price_range': '', 'all_histogram': {'1': 3, '3': 0, '2': 0, '5': 27, '4': 5}, 'release_date': '2014-12-21', 'all_rating_count': 35, 'permissions': ['full network access', 'modify or delete the contents of your USB storage', 'read the contents of your USB storage', 'prevent device from sleeping'], 'status_date': 'January 22, 2018', 'genre_id': 'TOOLS'}
# {'content_rating': 'Everyone', 'app_name': 'AppLock : Lock Apps with Fingerprint Security', 'content_rating_info': '', 'publisher_id_num': '4972703874721200202', 'requires_os': '5.0 and up', 'related': {'related_apps': ['com.hyperspeed.rocket.applock.free', 'com.multilock', 'caller.live.freeapps.phoneplus', 'net.bigdatacloud.iptools', 'com.shining.phone.flash.call.screen.wallpaper.theme', 'com.calculator.hide.photo.videolock', 'messenger.chat.social.messenger', 'com.domobile.doscan', 'com.melonsapp.privacymessenger', 'com.domobile.lockscreen', 'speedup.phone.space.booster.antivirus.clean', 'com.ludashi.multspace.addon.arm32', 'allinone.messenger.socialmedia.messages.lite', 'qr.code.qrcode.barcode.scanner.reader.generator', 'com.textu.sms.privacy.messenger', 'com.all.clean.cleanmaster.junkclean', 'com.domobile.messenger', 'com.rvappstudios.applock.protect.lock.app', 'com.clean.expert.boost.cache', 'com.privac.tools.applock', 'flashlight.flashlight.flashlight.pro', 'com.ludashi.superlock', 'com.ludashi.dualspace.addon.arm32', 'qrcodereader.barcodescanner.scannerapp.qrscanner', 'com.fast_cache_junk_cleaner.booster_master', 'com.protect.applock.stronglock', 'io.enpass.app', 'caller.live.freeapps.callblocker', 'com.genius.cleaner.master', 'com.notification.cleaner'], 'more_from_developer': ['free.stylish.text.stylish.fonts.fancytext', 'freemusic.offline.player.music.free.apps.songs.mp3', 'qr.code.reader.barcode.scanner.qrcodeScanner']}, 'video_urls': [], 'file_size': '9.0M', 'publisher_name': 'Text Styler - Appytome Apps', 'id': 'app.locker.fingerprint.applock.lockapps', 'price_currency': 'USD', 'genres': ['Tools'], 'app_type': 'APPLICATION', 'icon_url': 'https://lh3.googleusercontent.com/S4e70_6yf0C2K8GKnUOKUJXPz8rGGZvEYsrZ4ypqzZwZT8QihNQI5BKcnSSx2H6QuqE', 'interactive_elements': '', 'version': '1.0.7', 'publisher_url': '', 'whats_new': '📸 Improved Intruder Selfie for Android 9.0\n🔐 More stable & much better app lock experience\n📅 Change app icon to hide the app locker\n💯 Performance improved, works better on all devices\n✨ UI layout improvements\n🆗 Minor bug fixes\n👥 Fixed user feedback issues\n🚀 Enhanced privacy protection\n\nWe keep bringing new updates to Google Play regularly to constantly improve speed, reliability, performance, fix bugs and add new features.  \n\nSo keep sharing your feedback so we can serve you better!', 'publisher_id': 'Text Styler - Appytome Apps', 'price': 'Free', 'screenshot_urls': ['https://lh3.googleusercontent.com/QvJk2uIY4LvQtFAgtTIiiL5rIoE0OU6UAg0mQ21Cjy9NBWlyZDm06O-DMeG1THuDhFs', 'https://lh3.googleusercontent.com/GqxwXA3nNtF_YCoMXj8gs2wYFqL0IT30-qvO6grQU46XSJoPgYfx_H-3E-_xa2_n8w', 'https://lh3.googleusercontent.com/LY2z-dof_VO4eXcx9rG_BY_QF71vz0YuC3R5o_tV-WGRXqMmAkxDJkjI1fPbnTn-JQ', 'https://lh3.googleusercontent.com/20QUHiTmBVGrvJ5SFZMJSJgTu8ILWDij3wjPcw2V0aLpuO66FFeqIWln3U2NIbLE-dp7', 'https://lh3.googleusercontent.com/jIKSsaFX_7DFEfbTI6rGPohbShMURIjy6JbQT5Df79fG_f63N7TceOsknGMk8BMK6aI', 'https://lh3.googleusercontent.com/OnMg_q2uO-wisLwrBRhlWwVlmqRD7shgvF-PehfTyndjMlgIhscfrDjHxgZ3i0H-29E', 'https://lh3.googleusercontent.com/SPvvicmZQuA4Y-587jmuyKJ7sBKE6htZ_5pADn-pwdM7j8D-IxLfQtCkayuZutY9Ow', 'https://lh3.googleusercontent.com/8GzxXY3mW9XZXFt9OJWF75WEnsgk2lLh7iVOV_He_nARQteRGOsFvbeHE7c5l9rxFg'], 'status': 'updated', 'publisher_email': 'apps@appytome.com', 'description': 'The favourite app lock on playstore. Protect your privacy  and lock apps securely using fingerprint or pattern lock<br><br>☞ Smart  App Lock can lock Facebook, Whatsapp, Gallery, Messenger, Snapchat, Instagram, SMS, Contacts, Gmail, Settings, incoming calls and any app you choose. Prevent unauthorized access and guard privacy. Ensure security.<br>☞ Smart App Lock can hide pictures and videos. Hidden pictures and videos are vanished from Gallery and only visible in the photo and video vault. Protect private memories easily. No pin, no way.<br>☞Smart App Lock has random keyboard and invisible pattern lock. No more worry people m ...
# {'content_rating': 'Everyone', 'app_name': 'Resultado do Treino', 'content_rating_info': '', 'publisher_id_num': '5380584931784822871', 'requires_os': '5.0 and up', 'related': {'related_apps': ['com.hulu.plus', 'com.venmo', 'tv.pluto.android', 'com.youmusic.magictiles', 'com.enflick.android.TextNow', 'com.rovio.baba', 'com.paypal.android.p2pmobile', 'com.fancyclean.boost', 'com.pixel.art.coloring.color.number', 'com.evilclicker.evilclicker', 'com.outfit7.mytalkingtom2', 'com.waze', 'com.life360.android.safetymapd', 'com.ebay.mobile', 'com.lealApps.pedro.gymWorkoutPlan', 'com.insplisity.ultimateworkoutnutrition', 'com.ntstudio.thirty.days.fitness.challenge', 'br.com.delxmobile.tabata', 'com.bluecorner.totalgym', 'com.water.reminder.perfect', 'com.rarus.gyms', 'com.insplisity.ultimatefullbodyworkouts', 'com.jmsoft.heartbeat', 'joze.gymworkouts.health.gymworkouts', 'net.wordbit.enpt', 'com.gen.workoutme', 'com.setegraus.conjugacao', 'com.fitness.musicsounds', 'com.ejercicioscaseros', 'de.streetkickers'], 'more_from_developer': []}, 'video_urls': [], 'file_size': '23M', 'publisher_name': 'Resultado do Treino', 'id': 'com.resultadodotreino', 'price_currency': 'USD', 'genres': ['Health & Fitness'], 'app_type': 'APPLICATION', 'icon_url': 'https://lh3.googleusercontent.com/nUdMuQdoUMgl7zRQwQBEzSxMtEGvNZ2_RdEKnTnSAv6sw-hH37-3zL_fm0RNpqxBhbk', 'interactive_elements': '', 'version': '2.20.0', 'publisher_url': 'http://resultadodotreino.com', 'whats_new': 'Querido usuário, nosso leitor de releases preferido, temos uma novidade importante! Nós te ouvimos, juntamos os feedbacks e te entregamos ainda mais autonomia. Agora você pode incluir e editar seus resultados de bioimpedancia no App! \n\nTem uma balança em casa? Pode registrar! \n\nPassou no nutricionista e quer atualizar o resultado? Liberado também! \n\nSeu resultado, na palma da mão 🤳', 'publisher_id': 'Resultado do Treino', 'price': 'Free', 'screenshot_urls': ['https://lh3.googleusercontent.com/Par9RUUFnVVLUvqlDk9qMDzlIGw8mkEtPDJMsVIsZpySj2kqehdBiRePNkFPyvGMKQ', 'https://lh3.googleusercontent.com/VFp40Y90zCTEd1_bEdiysXMoy9KR9Q5VA3ChCBhRa6zM9WeV_5hcgGToZ3S0zEkMcHI', 'https://lh3.googleusercontent.com/kS-X4asGqDRcsxBN789PnZJRQMdn9JPtEOfpAwuCUFvZbPaBXISn8yLTnxwNJ-7apAGg', 'https://lh3.googleusercontent.com/KqFmxRLr6HbhA2mX9gCs3IwN1Fl41ZWBSn3_1T8B_GRD39GP2Tq5wOGfuRWnIFOiZ9s', 'https://lh3.googleusercontent.com/MEE8YBtaNFhw2wXDijIcCh7Ly40NJ_RzFgpGKeh3AY0AthGw_ha7ipqJ0pWDNXZ53RA', 'https://lh3.googleusercontent.com/JErRYkS27rf_yQCC9LKGaMrnqbVGGAki3trdyyr54DgHZ43hTDw_4qOuhHbXeyllLQ', 'https://lh3.googleusercontent.com/bcq8d1WKnoY2otAM3tNXnNpfeKOQI5_Xbe7bbVZfhlE7KU8kBk19NbTMQhOaqx2MGvw'], 'status': 'updated', 'publisher_email': 'app@resultadodotreino.com', 'description': 'O seu treino agora ficou completo!<br><br>Com o Resultado do Treino voce consegue acompanhar a sua evolução de percentual de gordura, massa magra, gordura visceral e muito mais.<br><br>Para ajudar voce a turbinar ainda mais os seus resultados e garantir que voce atinja seus objetivos, há ainda sugestões de cardápios, chat com a nutricionista (versão paga), scanner de produtos industrializados e você ainda pode mandar foto das suas refeições para as nossas nutricionistas avaliar!<br><br>Aproveite e compare a sua evolução com a dos seus colegas!', 'price_value': 0.0, 'all_rating': 4.8, 'store_url': 'https://play.google.com/store/apps/details?id=com.resultadodotreino', 'downloads': '1,000+', 'publisher_address': 'R. Me. Cabrini, 462 - Vila Mariana, São Paulo - SP, 04020-040', 'status_unix_timestamp': 1556836365, 'genre': 'Health & Fitness', 'bundle_id': 'com.resultadodotreino', 'genre_ids': ['HEALTH_AND_FITNESS'], 'iap_price_range': '', 'all_histogram': {'1': 1, '3': 0, '2': 0, '5': 23, '4': 0}, 'release_date': '2018-12-14', 'all_rating_count': 24, 'translated_description': 'Your workout is now complete!<br><br>With the result of the training you can follow your evolution of percentage of fat, lean mass, visceral fat and more. ...
# {'content_rating': 'Everyone', 'app_name': 'Frog VLE SMK Rawang', 'top_developer': False, 'publisher_id_num': '7008159404833265528', 'requires_os': '2.3 and up', 'related': {'related_apps': ['com.mcdonalds.app', 'com.pinterest', 'com.h8games.blocksbuster', 'com.amanotes.pamadancingroad', 'com.netmarble.btsw', 'com.zhiliaoapp.musically', 'com.squareup.cash', 'com.contextlogic.wish', 'com.matteljv.uno', 'com.youmusic.magictiles', 'com.dd.doordash', 'com.exordium.pottery', 'tv.pluto.android', 'com.playgendary.ktb2', 'com.tubitv', 'io.voodoo.holeio', 'io.voodoo.paper2', 'com.pandora.android', 'com.particlenews.newsbreak', 'com.colorhole.game', 'com.amazon.mShop.android.shopping', 'com.hulu.plus', 'com.ubercab', 'com.walmart.android', 'com.enflick.android.TextNow', 'com.playrix.gardenscapes', 'com.playrix.township', 'com.colorup.game', 'com.neonplay.casualrollersplat2', 'com.kiloo.subwaysurf'], 'more_from_developer': []}, 'video_urls': [], 'file_size': '4.1M', 'publisher_name': 'WATASHIAZIZI', 'id': 'com.wSMKRawang', 'price_currency': 'USD', 'genres': ['Education'], 'app_type': 'APPLICATION', 'icon_url': 'https://lh3.googleusercontent.com/-j03QzD7EhfVHuuomiVbagYQP3vg6v1ECL_AipoPaleHb_sqa8eD2Q5yi1Qy1YLxx_I9', 'content_rating_info': '', 'interactive_elements': '', 'version': '1.0', 'publisher_url': 'http://watashiazizi.com', 'whats_new': '', 'publisher_id': 'WATASHIAZIZI', 'price': 'Free', 'screenshot_urls': ['https://lh3.googleusercontent.com/0TnRBVj9koScMU9ZOHx7bgoIKedBmRkhSuQAHQXu8snrpfSkCPf14GvrWnPk6c2xBwE', 'https://lh3.googleusercontent.com/KZtM0iE6sZ7tfqGfdrnPIWx5Ho5awA228NYNHtiDgV9MsHCkr8yhCYLSjCSCOH_My9I'], 'status': 'updated', 'publisher_email': 'support@watashiazizi.com', 'description': 'Aplikasi untuk log masuk ke sistem pembelajaran maya Frog VLE SMK Rawang.<br><br>Pengguna aplikasi juga boleh mendapatkan maklumat Frog ID dan kata laluan untuk log masuk ke dalam sistem dengan hanya menggunakan telefon bimbit.', 'price_value': 0.0, 'all_rating': 0.0, 'store_url': 'https://play.google.com/store/apps/details?id=com.wSMKRawang', 'downloads': '100+', 'publisher_address': 'SK BANDAR TASIK PUTERI, 48000 RAWANG, SELANGOR', 'status_unix_timestamp': 1462889251, 'genre': 'Education', 'bundle_id': 'com.wSMKRawang', 'genre_ids': ['EDUCATION'], 'iap_price_range': '', 'all_histogram': {}, 'release_date': '2016-05-10', 'all_rating_count': 0, 'permissions': ['prevent device from sleeping', 'view network connections', 'full network access', 'receive data from Internet', 'run at startup', 'draw over other apps', 'read phone status and identity'], 'status_date': 'May 10, 2016', 'genre_id': 'EDUCATION'}
# {'content_rating': 'Everyone', 'app_name': '隨身佛經 華嚴經 Portable Sudra', 'top_developer': False, 'publisher_id_num': '7085084194566259093', 'requires_os': '4.0.3 and up', 'related': {'related_apps': ['com.particlenews.newsbreak', 'com.hulu.plus', 'com.pandora.android', 'com.azurinteractive.humanevolution', 'com.playgendary.tom', 'io.voodoo.paper2', 'com.dd.doordash', 'com.squareup.cash', 'com.amazon.avod.thirdpartyclient', 'com.contextlogic.wish', 'com.lilithgame.hgame.gp', 'com.youmusic.magictiles', 'com.matchington.mansion', 'com.magjg.roundhit', 'com.h8games.helixjump', 'com.ubercab', 'com.peoplefun.wordcross', 'com.amazon.mShop.android.shopping', 'com.kiloo.subwaysurf', 'com.walmart.android', 'com.offerup', 'com.abtnprojects.ambatana', 'com.tencent.ig', 'com.enflick.android.TextNow', 'com.playrix.township', 'pampam.ibf2', 'com.azurgames.stackball', 'com.mgc.runnergame', 'com.facebook.orca', 'com.snapchat.android'], 'more_from_developer': ['smallhubsgabrielle.tang_poem_300_paid_version', 'com.tabata.s.michael.rope_skipping_pro', 'smallhubsgabrielle.yizhuan_3', 'smallhubsgabrielle.yizhuan_2', 'smallhubsgabrielle.yizhuan', 'smallhubsgabrielle.chinese_couplet', 'smallhubsgabrielle.shiji', 'smallhubsgabrielle.chajing', 'www.smallhubs.com', 'smallhubsgabrielle.wenzi', 'smallhubsgabrielle.wuzhenpian', 'smallhubsgabrielle.shanghanlun', 'smallhubsgabrielle.cibei_xinshishici', 'smallhubsgabrielle.basicbuddhism', 'demo.cantonesesurvivalkit', 'smallhubsgabrielle.huangdineijing', 'smallhubsgabrielle.weishipian_1', 'smallhubsgabrielle.lun_yu', 'smallhubsgabrielle.bio_note', 'smallhubsgabrielle.poetry_dictionary', 'gabrielle.han', 'smallhubsgabrielle.buddhistscripts', 'smallhubsgabrielle.leyanjing', 'smallhubsgabrielle.eng_sutra', 'smallhubsgabrielle.buddhistcriptures', 'smallhubsgabrielle.sankepaiqi', 'smallhubsgabrielle.erpaiqian', 'smallhubsgabrielle.rongzhaisuibi', 'smallhubsgabrielle.yishimingyan', 'smallhubsgabrielle.zhuzijiaxun', 'smallhubsgabrielle.taixuanjing', 'smallhubsgabrielle.sanlve', 'gabrielle.ninnanonihongo', 'smallhubsgabrielle.fuyining', 'smallhubsgabrielle.rulinwaishi', 'smallhubsgabrielle.yizhoushu', 'smallhubsgabrielle.datangxiyuji', 'smallhubsgabrielle.fushengliuji', 'smallhubsgabrielle.Buddhist_sutra', 'smallhubsgabrielle.suiyuanshihua', 'smallhubsgabrielle.nongsanjiyao', 'smallhubsgabrielle.chenshu', 'smallhubsgabrielle.jingshitongyan', 'smallhubsgabrielle.jingshihengyan', 'smallhubsgabrielle.chukepaianjingqi', 'smallhubsgabrielle.jiandengxinhua', 'smallhubsgabrielle.niehaihua', 'smallhubsgabrielle.erya', 'smallhubsgabrielle.bowuzhi', 'smallhubsgabrielle.shuoyuan', 'smallhubsgabrielle.laocanyouji', 'smallhubsgabrielle.guhuapinlv', 'smallhubsgabrielle.mutianzizhuan', 'smallhubsgabrielle.laocanyoujixuji', 'smallhubsgabrielle.bencaogangmu', 'smallhubsgabrielle.kanji_list', 'smallhubsgabrielle.kanji_List_Dic', 'smallhubsgabrielle.zizhitongjian', 'smallhubsgabrielle.portable_chinese_full', 'smallhubsgabrielle.portable_chinese_xianqin', 'smallhubsgabrielle.cantonese_phrasebook', 'smallhubsgabrielle.yuwenxixuejichuzhishi', 'smallhubsgabrielle.portable_chinese_sung', 'smallhubsgabrielle.portable_chinese_liang', 'smallhubsgabrielle.portable_chinese_tang_1', 'smallhubsgabrielle.portable_chinese_ming', 'smallhubsgabrielle.weijin', 'smallhubsgabrielle.nanbei', 'smallhubsgabrielle.portable_chinese', 'smallhubsgabrielle.houhanshu_2', 'smallhubsgabrielle.houhanshu_1', 'smallhubsgabrielle.houhanshu', 'smallhubsgabrielle.xunzi', 'smallhubsgabrielle.zhenguanzhengyao', 'smallhubsgabrielle.dizangpusazhuanji', 'smallhubsgabrielle.hongloumeng', 'smallhubsgabrielle.wenchangxiaojing', 'smallhubsgabrielle.guanzi', 'smallhubsgabrielle.huainanzi', 'smallhubsgabrielle.soushenhouji', 'smallhubsgabrielle.shuzhujing', 'smallhubsgabrielle.shuikudi', 'smallhubsgabrielle.liji', 'smallhubsgabrielle.youxueqionglin', 'smallhubsgabrielle.zhouli', 'smallhubsgabrielle.lunheng', 'smallhubsgabrielle.kongzijiayu', 'smallhubsgabrielle.weiliaozi', 'smallhubsga ...
# ...
c_D8IA99', 'com.mobincube.seattle_hotels_us.sc_D8WLU8', 'localhotel.southkoreaseoul', 'localhotel.chinashanghai', 'localhotel.chinashenzhen', 'bestcarrental.germanyfrankfurt', 'iluvacations.germanyfrankfurt', 'localhotel.bulgariasofia', 'localhotel.russiastpetersburg', 'localhotel.australiasydney', 'localhotel.taiwantaipei', 'localhotel.ustampa', 'localhotel.israeltelaviv', 'localhotel.japantokyo', 'localhotel.italyvenice', 'localhotel.austriavienna', 'iluvacations.uschicago', 'iluvacations.netherlandsamsterdam', 'bestcarrental.costaricasanjose', 'iluvacations.costaricasanjose', 'iluvacations.thailandbangkok', 'bestcarrental.thailandbangkok', 'iluvacations.malaysiakualalumpur', 'bestcarrental.malaysiakualalumpur', 'iluvacations.mexicocancun', 'bestcarrental.mexicocancun', 'iluvacations.ukcambridge', 'bestcarrental.ukcambridge', 'iluvacations.ukcardiff', 'bestcarrental.ukcardiff', 'bestcarrental.ukleeds', 'bestcarrental.ukinverness', 'bestcarrental.ukaberdeen', 'iluvacations.newyorkcit ...
# {'content_rating': 'Teen', 'app_name': 'Wow Jax', 'content_rating_info': '', 'publisher_id_num': '7892119579066730755', 'requires_os': '4.0.3 and up', 'related': {'related_apps': ['com.cassette.aquapark', 'com.zhiliaoapp.musically', 'com.remind101', 'com.playrix.homescapes', 'com.contextlogic.wish', 'com.roblox.client', 'com.classdojo.android', 'com.playrix.township', 'com.squareup.cash', 'com.dd.doordash', 'com.walmart.android', 'com.amazon.mShop.android.shopping', 'com.bydeluxe.d3.android.program.starz', 'com.pandora.android', 'com.ubercab', 'com.amazon.avod.thirdpartyclient', 'tv.pluto.android', 'com.rovio.baba', 'com.hulu.plus', 'com.venmo', 'me.lyft.android', 'com.enflick.android.TextNow', 'com.microsoft.office.outlook', 'com.pixel.art.coloring.color.number', 'com.peoplefun.wordcross', 'com.abtnprojects.ambatana', 'io.voodoo.holeio', 'com.miniclip.eightballpool', 'com.waze', 'com.ebay.mobile'], 'more_from_developer': ['com.imaginamos.motorola', 'com.imaginamos.motorola.v2', 'com.imaginamos.albumpanini', 'com.imaginamos.cristovision', 'com.imaginamos.ypo']}, 'video_urls': [], 'file_size': '20M', 'publisher_name': 'JAIRO RUIZ MARIN', 'id': 'com.wowjax', 'price_currency': 'USD', 'genres': ['Social'], 'app_type': 'APPLICATION', 'icon_url': 'https://lh3.googleusercontent.com/dLKIdGQaU0tv7I_Ms114w3RwHTE3EhB6BjNEpkovtGe9FVAXMSFz2FAZ1gmxY3gQhDU', 'interactive_elements': 'Users Interact', 'version': '1.36', 'publisher_url': 'http://www.wowjax.com', 'whats_new': 'Pruebas', 'publisher_id': 'JAIRO RUIZ MARIN', 'price': 'Free', 'screenshot_urls': ['https://lh3.googleusercontent.com/3-_9yqeS4DHBANBMv_kVYtvFnG9U-tDTAFIO9iBjESzV5ti9KcYE53wp9JbnQM7QweM', 'https://lh3.googleusercontent.com/0SZxy0zzcaorOzM-FCyRLxYxBTjtfIB_18WS7EPtit2DL1G1InU_i3dL6t_KuuYRBpU', 'https://lh3.googleusercontent.com/rnBsukBd0WAo7J94BfMOhpjqgIUnD2-tZH9N1nDQRCDOC4CxIYnaw_ku2DshLX6k7A'], 'status': 'updated', 'publisher_email': 'jairo@wowjax.com', 'description': 'WOW JAX es una comunidad en línea para mascotas dedicada a conectar todos los<br>servicios que tienen como objetivo su felicidad y el bienestar creando un espacio para compartir el amor por ellos.<br><br>A través de nuestra plataforma puedes conectarte con otras mascotas; capturar y compartir momentos con imágenes, videos o pensamientos entre tu comunidad, Crear recordatorios de asuntos importantes para tu mascota, y encontrar en nuestro directorio los establecimientos dedicados al cuidado y felicidad de ellos.', 'price_value': 0.0, 'all_rating': 4.7, 'store_url': 'https://play.google.com/store/apps/details?id=com.wowjax', 'downloads': '500+', 'publisher_address': '', 'status_unix_timestamp': 1556955614, 'genre': 'Social', 'bundle_id': 'com.wowjax', 'genre_ids': ['SOCIAL'], 'iap_price_range': '', 'all_histogram': {'1': 1, '3': 0, '2': 0, '5': 18, '4': 2}, 'release_date': '2017-08-29', 'all_rating_count': 21, 'translated_description': 'JAX WOW is an online community dedicated to connecting pet all<br>services that target their happiness and well-being by creating a space to share love for them.<br><br>Through our platform you can connect with other pets; capture and share moments with images, videos or thoughts from your community, create reminders for important issues for your pet and find in our directory establishments for the care and happiness of them.', 'permissions': ['prevent device from sleeping', 'view network connections', 'full network access', 'directly call phone numbers', 'receive data from Internet', 'run at startup', 'modify or delete the contents of your USB storage', 'read the contents of your USB storage', 'take pictures and videos', 'control vibration', 'read phone status and identity'], 'status_date': 'May 4, 2019', 'genre_id': 'SOCIAL'}
# {'content_rating': 'Everyone', 'app_name': 'Lassi Making Recipes Videos', 'content_rating_info': '', 'publisher_id_num': '9170300705958475839', 'requires_os': '4.0.3 and up', 'related': {'related_apps': ['com.whatsapp', 'com.instagram.android', 'com.remind101', 'com.netflix.mediaclient', 'com.classdojo.android', 'com.cassette.aquapark', 'com.facebook.katana', 'com.spotify.music', 'com.roblox.client', 'com.venmo', 'com.bydeluxe.d3.android.program.starz', 'com.bitmango.go.linepuzzlepipeart', 'com.peoplefun.wordstacks', 'com.espn.fantasy.lm.football', 'com.groupme.android', 'com.creditkarma.mobile', 'com.life360.android.safetymapd', 'com.discord', 'tv.pluto.android', 'com.soundcloud.android', 'com.ubercab.eats', 'com.microblink.photomath', 'com.sec.android.easyMover', 'com.instructure.candroid', 'com.fungames.sniper3d', 'net.zedge.android', 'com.samsung.android.app.notes', 'com.wayfair.wayfair', 'com.zellepay.zelle', 'com.habby.archero'], 'more_from_developer': ['com.kundaldevelopersapp.manicurespavideoapp', 'com.kundaldevelopersapp.piyanotraininvideoapp', 'com.kundaldevelopersapp.pastafoodrecipesvideo', 'com.kundaldevelopersapp.maxicanfoodrecipesvideoapp', 'com.kundaldevelopersapp.gangnamdancevideo', 'com.kundaldevelopersapp.basketballvideoapp', 'com.kundaldevelopersapp.shrivaibhavmahalakshi', 'com.kundaldevelopersapp.bharatnatyamdancelearningvideoapp
# {'content_rating': 'Everyone', 'app_name': 'Contá Conmigo', 'content_rating_info': '', 'publisher_id_num': '8497018357554474559', 'requires_os': '4.0 and up', 'related': {'related_apps': ['com.zhiliaoapp.musically', 'com.squareup.cash', 'com.contextlogic.wish', 'com.matteljv.uno', 'com.youmusic.magictiles', 'com.dd.doordash', 'com.exordium.pottery', 'tv.pluto.android', 'com.tubitv', 'io.voodoo.holeio', 'io.voodoo.paper2', 'com.particlenews.newsbreak', 'com.amazon.mShop.android.shopping', 'com.hulu.plus', 'com.lightricks.pixaloop', 'com.ubercab', 'com.walmart.android', 'com.enflick.android.TextNow', 'com.playrix.gardenscapes', 'com.playrix.township', 'com.h8games.blocksbuster', 'com.neonplay.casualrollersplat2', 'com.kiloo.subwaysurf', 'com.venmo', 'paint.by.number.pixel.art.coloring.drawing.puzzle', 'com.belcorp.ffvv', 'com.fundacionmapfre.sosrespira', 'es.odilo.gentera', 'com.rindegastos.rindegastos2', 'teorico.manejo'], 'more_from_developer': ['appinventor.ai_TorresFernandoGab.FoneticApp_checkpoint1']}, 'video_urls': ['https://www.youtube.com/embed/rlIZqiHiK6M?ps=play&vq=large&rel=0&autohide=1&showinfo=0'], 'file_size': '7.8M', 'publisher_name': 'Proyecto Juega Juampi!', 'id': 'appinventor.ai_juegajuampi.LosNumerosApp', 'price_currency': 'USD', 'genres': ['Entertainment'], 'app_type': 'APPLICATION', 'icon_url': 'https://lh3.googleusercontent.com/iaKLyHM1f33bf_ZF1AVOL0eUDn2itL7wu88sRfc0AsjeNZbzvBhmxaTxpp5ioSR_4Yc', 'interactive_elements': '', 'version': '1.0', 'publisher_url': 'http://www.juegajuampi.org', 'whats_new': '', 'publisher_id': 'Proyecto Juega Juampi!', 'price': 'Free', 'screenshot_urls': ['https://lh3.googleusercontent.com/soJhNbW7lDjvOY6rBdZZ1ZxX1Bnb3UYaFpLtY_iIAHddipZJ0psbrJzXJ6ycj00mCA', 'https://lh3.googleusercontent.com/LGchYEgkkQb9EP8mVaunBtW2p5xYvrh-vTkA3guLQE7NDFxLxeLIhkZ_vpVYtb1AS5s'], 'status': 'updated', 'publisher_email': 'info@juegajuampi.org', 'description': 'Es una aplicación de celular que consiste en la enseñanza de matemáticas, en particular los números. Se compone de diferentes modos de juegos, de los cuales se va enseñando diferentes aspectos. <br>Primer modo: “Numero”: La persona  tiene la posibilidad de ir conociendo cada número.Segundo modo: “Continuidad”:La persona puede aprender cuál es la continuidad de cada número (es decir, qué le sigue al número, qué viene antes y qué viene después).Tercer modo: “Representación”:Consiste en enseñar y entender la cantidad que representa cada número.<br>     Todos estos modos se van enseñando a través del juego y la persona tiene la posibilidad de utilizarlo las veces que quiera.      Esta aplicación funciona para sistemas operativos de Android y se encuentra disponible en el Play Store para su descarga. <br>    La misma no contiene publicidad, entendemos que es importante que no tenga publicidad para no distraer a la persona que lo utilice.', 'price_value': 0.0, 'all_rating': 0.0, 'store_url': 'https://play.google.com/store/apps/details?id=appinventor.ai_juegajuampi.LosNumerosApp', 'downloads': '50+', 'publisher_address': '', 'status_unix_timestamp': 1537125691, 'genre': 'Entertainment', 'bundle_id': 'appinventor.ai_juegajuampi.LosNumerosApp', 'genre_ids': ['ENTERTAINMENT'], 'iap_price_range': '', 'all_histogram': {'1': 0, '3': 0, '2': 0, '5': 3, '4': 0}, 'release_date': '2018-09-12', 'all_rating_count': 0, 'translated_description': 'It is a cell phone application that consists of teaching mathematics, particularly numbers. It consists of different game modes, of which different aspects are taught.<br>First mode: &quot;Number&quot;: The person has the possibility of knowing each number. Second way: &quot;Continuity&quot;: The person can learn which is the continuity of each number (that is, what follows the number, what comes before and what comes next). Third way: &quot;Representation&quot;: It consists of teaching and understanding the amount that each number represents.<br>\xa0\xa0\xa0\xa0\xa0All these modes are taught through the game and the person ...

# %%
json_record.keys()
# Out:
# dict_keys(['content_rating', 'app_name', 'content_rating_info', 'publisher_id_num', 'requires_os', 'related', 'video_urls', 'file_size', 'publisher_name', 'id', 'price_currency', 'genres', 'app_type', 'icon_url', 'interactive_elements', 'version', 'publisher_url', 'whats_new', 'publisher_id', 'price', 'screenshot_urls', 'status', 'publisher_email', 'description', 'price_value', 'all_rating', 'store_url', 'downloads', 'publisher_address', 'status_unix_timestamp', 'genre', 'bundle_id', 'genre_ids', 'iap_price_range', 'all_histogram', 'release_date', 'all_rating_count', 'translated_description', 'permissions', 'status_date', 'genre_id'])

# %%
import pandas as pd
from pandas.io.json import json_normalize

df = json_normalize(json_record)

for each in json_record:
    df.append(json_normalize(json_record), ignore_index = True) 
    
df['publisher_id_num']
df
# Out:
#    all_histogram.1  all_histogram.2  all_histogram.3  all_histogram.4  \
# 0                0                0                0                0
#
#    all_histogram.5  all_rating  all_rating_count       app_name     app_type  \
# 0                3         0.0                 0  Contá Conmigo  APPLICATION
#
#                                   bundle_id  ... requires_os  \
# 0  appinventor.ai_juegajuampi.LosNumerosApp  ...  4.0 and up
#
#                                      screenshot_urls   status  \
# 0  [https://lh3.googleusercontent.com/soJhNbW7lDj...  updated
#
#           status_date status_unix_timestamp  \
# 0  September 16, 2018            1537125691
#
#                                            store_url  \
# 0  https://play.google.com/store/apps/details?id=...
#
#                               translated_description version  \
# 0  It is a cell phone application that consists o...     1.0
#
#                                           video_urls whats_new
# 0  [https://www.youtube.com/embed/rlIZqiHiK6M?ps=...
#
# [1 rows x 46 columns]

# %%
#print(data['items'][0]['volumeInfo']['authors'])
# pd.concat(
#     pd.DataFrame([response.json() for x in json_record.iter_lines()]),
#     ignore_index=True)

parsed = json.loads(response.text)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-0725b357fbad> in <module>
#       4 #     ignore_index=True)
#       5
# ----> 6 parsed = json.loads(response.text)
#
# ~/socos/impact-index/env/lib/python3.7/site-packages/requests/models.py in text(self)
#     850         encoding = self.encoding
#     851
# --> 852         if not self.content:
#     853             return str('')
#     854
#
# ~/socos/impact-index/env/lib/python3.7/site-packages/requests/models.py in content(self)
#     821             if self._content_consumed:
#     822                 raise RuntimeError(
# --> 823                     'The content for this response was already consumed')
#     824
#     825             if self.status_code == 0 or self.raw is None:
#
# RuntimeError: The content for this response was already consumed

# %%
for i in range(len(data['items'])):
    try:
        print(data['items'][i]['volumeInfo']['authors'])
    except KeyError:
        print('no author - ' + data['items'][i]['volumeInfo']['title'])
# Out:
# ["Tim O'Reilly", 'Sarah Milstein']
# ['Nick Bilton']
# ['David Pogue']
# ['Kristin Marciniak']
# ['Kevin Makice']
# ['Zeynep Tufekci']
# no author - Naked Truth Behind Social Media: Facebook and Twitter Tactics That Still Work
# ['Kyle Lacy']
# ['Matthew A. Russell', 'Matthew Russell']
# ['Mary Cross']

# %%
print(data['items'][6]['volumeInfo'])
# Out:
# {'title': 'Naked Truth Behind Social Media: Facebook and Twitter Tactics That Still Work', 'publisher': 'eBooks', 'readingModes': {'text': True, 'image': True}, 'printType': 'BOOK', 'averageRating': 3.0, 'ratingsCount': 1, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': 'preview-1.0.0', 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=qe_2_1rDrM0C&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=qe_2_1rDrM0C&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.com/books?id=qe_2_1rDrM0C&pg=PT6&dq=twitter&hl=&cd=7&source=gbs_api', 'infoLink': 'http://books.google.com/books?id=qe_2_1rDrM0C&dq=twitter&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/Naked_Truth_Behind_Social_Media_Facebook.html?hl=&id=qe_2_1rDrM0C'}

# %%
founders_lst = ['Anders Søndergaard', 'Thomas Scherning', 'Jette Wied Hatting', 'Helga Halkjær']

# %%
for founder in founders_lst:
    url = 'https://www.googleapis.com/books/v1/volumes?q=' + founder.split(' ')[0] + '%20' + founder.split()[1] + '&key=AIzaSyBYj9Nh9B_TEkwbffdw1_sz0gVOFXMAuHo'
    print(url)
#     resp = requests.get(url=url)
#     data = json.loads(resp.text)

# print(data)
# Out:
# https://www.googleapis.com/books/v1/volumes?q=Anders%20Søndergaard&key=AIzaSyBYj9Nh9B_TEkwbffdw1_sz0gVOFXMAuHo
# https://www.googleapis.com/books/v1/volumes?q=Thomas%20Scherning&key=AIzaSyBYj9Nh9B_TEkwbffdw1_sz0gVOFXMAuHo
# https://www.googleapis.com/books/v1/volumes?q=Jette%20Wied&key=AIzaSyBYj9Nh9B_TEkwbffdw1_sz0gVOFXMAuHo
# https://www.googleapis.com/books/v1/volumes?q=Helga%20Halkjær&key=AIzaSyBYj9Nh9B_TEkwbffdw1_sz0gVOFXMAuHo

# %%
url = 'https://www.googleapis.com/books/v1/volumes?q=codementor+inauthor:Weiting%20Liu&key=AIzaSyBYj9Nh9B_TEkwbffdw1_sz0gVOFXMAuHo'
print(url)
# Out:
# https://www.googleapis.com/books/v1/volumes?q=codementor+inauthor:Weiting%20Liu&key=AIzaSyBYj9Nh9B_TEkwbffdw1_sz0gVOFXMAuHo

# %%
url = 'https://www.googleapis.com/books/v1/volumes?q=inpublisher:Forbes&key=AIzaSyBYj9Nh9B_TEkwbffdw1_sz0gVOFXMAuHo'
print(url)
# Out:
# https://www.googleapis.com/books/v1/volumes?q=inpublisher:Forbes&key=AIzaSyBYj9Nh9B_TEkwbffdw1_sz0gVOFXMAuHo

# %%
url = 'https://www.googleapis.com/books/v1/volumes?q=inpublisher:Lickability&key=AIzaSyBYj9Nh9B_TEkwbffdw1_sz0gVOFXMAuHo'
print(url)
# Out:
# https://www.googleapis.com/books/v1/volumes?q=inpublisher:Lickability&key=AIzaSyBYj9Nh9B_TEkwbffdw1_sz0gVOFXMAuHo
