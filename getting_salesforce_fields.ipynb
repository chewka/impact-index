# %%
 lst = [('Id', '0036300000V24mrAAB'),
             ('IsDeleted', False),
             ('MasterRecordId', None),
             ('AccountId', '0016300000fJGUFAA4'),
             ('LastName', 'Smith'),
             ('FirstName', None),
             ('Salutation', None),
             ('MiddleName', None),
             ('Suffix', None),
             ('Name', 'Smith'),
             ('OtherStreet', None),
             ('OtherCity', None),
             ('OtherState', None),
             ('OtherPostalCode', None),
             ('OtherCountry', None),
             ('OtherLatitude', None),
             ('OtherLongitude', None),
             ('OtherGeocodeAccuracy', None),
             ('OtherAddress', None),
             ('MailingStreet', None),
             ('MailingCity', None),
             ('MailingState', None),
             ('MailingPostalCode', None),
             ('MailingCountry', None),
             ('MailingLatitude', None),
             ('MailingLongitude', None),
             ('MailingGeocodeAccuracy', None),
             ('MailingAddress', None),
             ('Phone', None),
             ('Fax', None),
             ('MobilePhone', None),
             ('HomePhone', None),
             ('OtherPhone', None),
             ('AssistantPhone', None),
             ('ReportsToId', None),
             ('Email', 'example@example.com'),
             ('Title', None),
             ('Department', None),
             ('AssistantName', None),
             ('LeadSource', None),
             ('Birthdate', None),
             ('Description', None),
             ('OwnerId', '005630000038KFZAA2'),
             ('HasOptedOutOfEmail', False),
             ('HasOptedOutOfFax', False),
             ('DoNotCall', False),
             ('CreatedDate', '2019-10-08T05:50:05.000+0000'),
             ('CreatedById', '005630000038KFZAA2'),
             ('LastModifiedDate', '2019-10-08T05:50:06.000+0000'),
             ('LastModifiedById', '005630000038KFZAA2'),
             ('SystemModstamp', '2019-10-08T05:50:06.000+0000'),
             ('LastActivityDate', None),
             ('LastCURequestDate', None),
             ('LastCUUpdateDate', None),
             ('LastViewedDate', '2019-10-08T05:50:37.000+0000'),
             ('LastReferencedDate', '2019-10-08T05:50:37.000+0000'),
             ('EmailBouncedReason', None),
             ('EmailBouncedDate', None),
             ('IsEmailBounced', False),
             ('PhotoUrl', '/services/images/photo/0036300000V24mrAAB'),
             ('Jigsaw', None),
             ('JigsawContactId', None),
             ('npe01__AlternateEmail__c', None),
             ('npe01__HomeEmail__c', 'example@example.com'),
             ('npe01__Home_Address__c', None),
             ('npe01__Last_Donation_Date__c', None),
             ('npe01__Lifetime_Giving_History_Amount__c', 0.0),
             ('npe01__Organization_Type__c', 'Household Account'),
             ('npe01__Other_Address__c', None),
             ('npe01__PreferredPhone__c', 'Home'),
             ('npe01__Preferred_Email__c', 'Personal'),
             ('npe01__Primary_Address_Type__c', None),
             ('npe01__Private__c', False),
             ('npe01__Secondary_Address_Type__c', None),
             ('npe01__SystemAccountProcessor__c', None),
             ('npe01__SystemIsIndividual__c', False),
             ('npe01__Type_of_Account__c', 'Individual'),
             ('npe01__WorkEmail__c', None),
             ('npe01__WorkPhone__c', None),
             ('npe01__Work_Address__c', None),
             ('npo02__AverageAmount__c', 0.0),
             ('npo02__Best_Gift_Year_Total__c', None),
             ('npo02__Best_Gift_Year__c', None),
             ('npo02__FirstCloseDate__c', None),
             ('npo02__Formula_HouseholdMailingAddress__c', '<br>'),
             ('npo02__Formula_HouseholdPhone__c', None),
             ('npo02__Household_Naming_Order__c', None),
             ('npo02__Household__c', None),
             ('npo02__LargestAmount__c', 0.0),
             ('npo02__LastCloseDateHH__c', None),
             ('npo02__LastCloseDate__c', None),
             ('npo02__LastMembershipAmount__c', 0.0),
             ('npo02__LastMembershipDate__c', None),
             ('npo02__LastMembershipLevel__c', None),
             ('npo02__LastMembershipOrigin__c', None),
             ('npo02__LastOppAmount__c', 0.0),
             ('npo02__MembershipEndDate__c', None),
             ('npo02__MembershipJoinDate__c', None),
             ('npo02__Naming_Exclusions__c', None),
             ('npo02__NumberOfClosedOpps__c', 0.0),
             ('npo02__NumberOfMembershipOpps__c', 0.0),
             ('npo02__OppAmount2YearsAgo__c', 0.0),
             ('npo02__OppAmountLastNDays__c', 0.0),
             ('npo02__OppAmountLastYearHH__c', 0.0),
             ('npo02__OppAmountLastYear__c', 0.0),
             ('npo02__OppAmountThisYearHH__c', 0.0),
             ('npo02__OppAmountThisYear__c', 0.0),
             ('npo02__OppsClosed2YearsAgo__c', 0.0),
             ('npo02__OppsClosedLastNDays__c', 0.0),
             ('npo02__OppsClosedLastYear__c', 0.0),
             ('npo02__OppsClosedThisYear__c', 0.0),
             ('npo02__SmallestAmount__c', 0.0),
             ('npo02__Soft_Credit_Last_Year__c', None),
             ('npo02__Soft_Credit_This_Year__c', None),
             ('npo02__Soft_Credit_Total__c', None),
             ('npo02__Soft_Credit_Two_Years_Ago__c', None),
             ('npo02__SystemHouseholdProcessor__c', None),
             ('npo02__TotalMembershipOppAmount__c', 0.0),
             ('npo02__TotalOppAmount__c', 0.0),
             ('npo02__Total_Household_Gifts__c', 0.0),
             ('npsp__Batch__c', None),
             ('npsp__Current_Address__c', None),
             ('npsp__HHId__c', '0016300000fJGUFAA4'),
             ('npsp__Primary_Affiliation__c', None),
             ('npsp__Soft_Credit_Last_N_Days__c', 0.0),
             ('npsp__is_Address_Override__c', False),
             ('GW_Volunteers__Unique_Volunteer_Count__c', 1.0),
             ('GW_Volunteers__Volunteer_Auto_Reminder_Email_Opt_Out__c',
              False),
             ('GW_Volunteers__Volunteer_Availability__c', None),
             ('GW_Volunteers__Volunteer_Last_Web_Signup_Date__c', None),
             ('GW_Volunteers__Volunteer_Manager_Notes__c', None),
             ('GW_Volunteers__Volunteer_Notes__c', None),
             ('GW_Volunteers__Volunteer_Organization__c', None),
             ('GW_Volunteers__Volunteer_Skills__c', None),
             ('GW_Volunteers__Volunteer_Status__c', None),
             ('GW_Volunteers__First_Volunteer_Date__c', None),
             ('GW_Volunteers__Last_Volunteer_Date__c', None),
             ('GW_Volunteers__Volunteer_Hours__c', 0.0),
             ('Member_Agree_With_Terms__c', False),
             ('npsp__Primary_Contact__c', True),
             ('npsp__Address_Verification_Status__c', None),
             ('npsp__Exclude_from_Household_Formal_Greeting__c', False),
             ('npsp__Exclude_from_Household_Informal_Greeting__c', False),
             ('npsp__Exclude_from_Household_Name__c', False),
             ('npsp__Deceased__c', False),
             ('npsp__Do_Not_Contact__c', False),
             ('npsp__First_Soft_Credit_Amount__c', None),
             ('npsp__First_Soft_Credit_Date__c', None),
             ('npsp__Largest_Soft_Credit_Amount__c', None),
             ('npsp__Largest_Soft_Credit_Date__c', None),
             ('npsp__Last_Soft_Credit_Amount__c', None),
             ('npsp__Last_Soft_Credit_Date__c', None),
             ('npsp__Number_of_Soft_Credits_Last_N_Days__c', None),
             ('npsp__Number_of_Soft_Credits_Last_Year__c', None),
             ('npsp__Number_of_Soft_Credits_This_Year__c', None),
             ('npsp__Number_of_Soft_Credits_Two_Years_Ago__c', None),
             ('npsp__Number_of_Soft_Credits__c', None),
             ('Category__c', None),
             ('Age__c', None),
             ('Personal_LinkedIn_URL__c', None),
             ('Entrepreneur__c', None),
             ('Personal_URL__c', None),
             ('Institutional_Investor__c', False),
             ('Service_Provider__c', None),
             ('Service_Provider_Other__c', None),
             ('Other__c', None),
             ('How_You_Identify__c', None),
             ('Your_Pronouns__c', None),
             ('Your_Pronouns_Other__c', None),
             ('Long_Contact_ID__c', '0036300000V24mrAAB'),
             ('Mentor_Date_Submitted__c', None),
             ('About_You__c', None),
             ('Total_Requests_to_Connect__c', 0.0),
             ('Seniority_Level__c', None),
             ('Name_of_Member_Company__c', None),
             ('FF_Yearly_Payment_Complete__c', False),
             ('FF_Monthly_Payment_Complete__c', False),
             ('of_Founder_Applications__c', None),
             ('Founder__c', False),
             ('Unsubscribe_Date__c', None),
             ('Industries__c', None),
             ('Other_Industries__c', None),
             ('Partner_Organizations__c', None),
             ('Year_of_Birth__c', None),
             ('Ethnicity_African_American__c', False),
             ('Ethnicity_Asian__c', False),
             ('Ethnicity_Caucasian__c', False),
             ('Ethnicity_Hispanic_Latino__c', False),
             ('Ethnicity_Native_American__c', False),
             ('Ethnicity_Native_Hawaiian_Pacific_Island__c', False),
             ('Ethnicity_Other__c', None),
             ('How_You_Identify_Lesbian__c', False),
             ('How_You_Identify_Gay__c', False),
             ('How_You_Identify_Bisexual__c', False),
             ('How_You_Identify_Transgender__c', False),
             ('How_You_Identify_Queer__c', False),
             ('How_You_Identify_Male__c', False),
             ('How_You_Identify_Female__c', False),
             ('How_You_Identify_Gender_Non_Conforming__c', False),
             ('How_You_Identify_Ally__c', False),
             ('Volunteer_Interest_Become_a_Mentor__c', False),
             ('Additional_Info_Veteran__c', False),
             ('Additional_Info_Disabled__c', False),
             ('Additional_Info_Immigrant__c', False),
             ('Additional_Info_Refugee__c', False),
             ('Additional_Info_Other__c', None),
             ('Chapter_Austin__c', False),
             ('Chapter_Boston__c', False),
             ('Chapter_Chicago__c', False),
             ('Chapter_Los_Angeles__c', False),
             ('Chapter_New_York__c', False),
             ('Chapter_San_Francisco__c', False),
             ('Visits_last_30_days__c', None),
             ('How_did_you_hear_about_StartOut__c', None),
             ('How_did_you_hear_about_StartOut_Other__c', None),
             ('Why_become_a_member__c', None),
             ('I_am_a_founder_investor_professional__c', None),
             ('Industries_for_Mentoring__c', None),
             ('Functional_Areas_for_Mentoring__c', None),
             ('Rating_Identify_in_Community__c', None),
             ('Rating_Geographic_Proximity__c', None),
             ('Rating_Functional_Expertise__c', None),
             ('Rating_Industry_Expertise__c', None),
             ('Describe_Your_Business__c', None),
             ('What_skills_or_experience__c', None),
             ('Why_do_you_want_to_be_a_mentor__c', None),
             ('Have_you_previously_been_a_mentor__c', None),
             ('Anything_else_you_would_like_to_share__c', None),
             ('Total_Amount_Invested__c', None),
             ('Growthlab_Cohort_number__c', None),
             ('AngelList_Profile_URL__c', None),
             ('Certify_I_am_Accredited__c', False),
             ('Investor_Check_all_that_apply__c', None),
             ('Investor_Industries_of_Interest__c', None),
             ('Stages_of_Interest__c', None),
             ('Underrepresented_founders_mandate__c', None),
             ('Underrepresented_founders_mandate_Other__c', None),
             ('Average_Ticket_Size__c', None),
             ('Geographical_Restrictions__c', None),
             ('Anything_else_to_share__c', None),
             ('Agree_with_Terms__c', False),
             ('Prefer_to_hear_exclusively_from__c', None),
             ('Company_Industries__c', None),
             ('Total_Requests_Received__c', 0.0),
             ('Mentee_Program_Status__c', None),
             ('Mentor_Program_Status__c', None),
             ('Investor_Program_Status__c', None),
             ('Legacy_CRM_Contact_Unique_ID__c', None),
             ('Searches_last_30_days__c', None),
             ('Lead_Founder_Looking_for_Support__c', False),
             ('Lead_Aspiring_Founder_Inspiration__c', False),
             ('GrowthLab_Program_Status__c', None),
             ('Fundraiser_Program_Status__c', None),
             ('of_Submissions__c', 0.0),
             ('NetworQ__c', None),
             ('Volunteer_Interest_Chapter_programming__c', False),
             ('of_Social_Media_Posts__c', 0.0),
             ('of_Rejections__c', 0.0),
             ('Lead_Investor_Looking_for_Deal_Flow__c', False),
             ('How_You_Identify_Other__c', None),
             ('Full_Name__c', 'Smith'),
             ('of_Email_Mentions__c', 0.0),
             ('Chapters__c', None),
             ('Volunteer_Interest_Outreach__c', False),
             ('Total_Successful_Matches_as_a_Mentor__c', None),
             ('Total_Successful_Matches_as_a_Mentee__c', None),
             ('Total_Successful_Matches__c', None),
             ('Total_Unsuccessful_Matches_as_a_Mentor__c', None),
             ('Total_Unsuccessful_Matches_as_a_Mentee__c', None),
             ('Total_Unsuccessful_Matches__c', None),
             ('Date_Added__c', '2019-10-08'),
             ('FA_Date_Applied__c', None),
             ('FA_Status__c', None),
             ('FA_Date_Approved__c', None),
             ('As_Mentor_Match_Status__c', None),
             ('Mentor_Name__c', None),
             ('Mentee_Name__c', None),
             ('As_Mentor_Date_Matched__c', None),
             ('As_Mentee_Match_Status__c', None),
             ('As_Mentee_Date_Matched__c', None),
             ('of_Rounds_Closed__c', None),
             ('of_Investments__c', None),
             ('Investor_Company_1_Name__c', None),
             ('Investor_Company_1_Role__c', None),
             ('Investor_Company_2_Name__c', None),
             ('Investor_Company_2_Role__c', None),
             ('Investor_Company_3_Name__c', None),
             ('Investor_Company_3_Role__c', None),
             ('Investor_Company_4_Name__c', None),
             ('Investor_Company_4_Role__c', None),
             ('Investor_Date_Submitted__c', None),
             ('Fundraiser_Date_Joined__c', None),
             ('Office_Hours_number_of_Sessions__c', None),
             ('Office_Hours_Last_Visit_Date__c', None),
             ('NetworQ_Date_of_1st_Visit__c', None),
             ('NetworQ_Total_Visits__c', None),
             ('NetworQ_Total_Searches__c', None),
             ('Profile_Photo__c', None),
             ('NetworQ_Last_Visit__c', None),
             ('Forum_Registered__c', False),
             ('Forum_Last_Activity__c', None),
             ('Lead_Potential_Donor__c', False),
             ('Lead_Interested_in_Mentoring__c', False),
             ('Lead_Local_StartOut_Community__c', False),
             ('Last_Event__c', None),
             ('Date_of_Last_Event__c', None),
             ('Total_Events_Registered__c', None),
             ('GrowthLab_number_of_Applications__c', None),
             ('Investor_Preferred_Email__c', None),
             ('Research_Downloaded_Paper__c', None),
             ('Research_Date_Downloaded__c', None),
             ('Total_Other_Amount_Fundraised__c', None),
             ('Total_SO_Amount_Fundraised__c', None),
             ('Total_Amount_Fundraised__c', None),
             ('Investor_Business_Address_1__c', None),
             ('Investor_Business_Address_2__c', None),
             ('Investor_Business_City__c', None),
             ('Investor_Business_Country__c', None),
             ('Investor_Business_State__c', None),
             ('Investor_Business_Zip_Code__c', None),
             ('Investor_Business_Phone__c', None),
             ('Investor_Industries_Other__c', None),
             ('Mentor_Phone__c', None),
             ('Mentor_Check_all_that_apply__c', None),
             ('Industries_for_Mentoring_Other__c', None),
             ('Functional_Areas_for_Mentoring_Other__c', None),
             ('Recruitment_Founder_Status__c', None),
             ('Founder_Recruit_Contact_Date__c', None),
             ('Recruitment_Founder_Contact_Note__c', None),
             ('Recruitment_Founder_Follow_Up_Date__c', None),
             ('Recruitment_Founder_Follow_Up_Note__c', None),
             ('Recruitment_Founder_Not_Interested_Date__c', None),
             ('Recruitment_Founder_Not_Interested_Note__c', None),
             ('Lead_Org_that_Supports_Founders__c', False),
             ('Recruitment_Mentor_Contacted_Date__c', None),
             ('Recruitment_Mentor_Contact_Note__c', None),
             ('Recruitment_Mentor_Follow_Up_Date__c', None),
             ('Recruitment_Mentor_Follow_Up_Note__c', None),
             ('Recruitment_Mentor_Not_Interested_Date__c', None),
             ('Recruitment_Mentor_Not_Interested_Note__c', None),
             ('Lead_Give_Back_Volunteering__c', False),
             ('Recruitment_Investor_Contacted_Date__c', None),
             ('Recruitment_Investor_Contact_Note__c', None),
             ('Recruitment_Investor_Follow_Up_Date__c', None),
             ('Recruitment_Investor_Follow_Up_Note__c', None),
             ('Recruitment_Investor_Not_Interested_Date__c', None),
             ('Recruitment_Investor_Not_Interested_Note__c', None),
             ('of_Blog_Mentions__c', 0.0),
             ('Ethnicity_Other_ckbx__c', False),
             ('How_You_Identify_Other_chbx__c', False),
             ('Additional_Info_Other_ckbx__c', False),
             ('Founder_Recruitment_Potential_Date__c', None),
             ('Founder_Recruitment_Potential_Note__c', None),
             ('Founder_Recruitment_Will_Join_Date__c', None),
             ('Founder_Recruitment_Will_Join_Note__c', None),
             ('Founder_Recruitment_Join_Follow_Up_Date__c', None),
             ('Founder_Recruitment_Join_Follow_Up_Note__c', None),
             ('Founder_Recruitment_Join_Confirmed_Date__c', None),
             ('Founder_Recruitment_Join_Confirmed_Note__c', None),
             ('Founder_Recruitment_Not_A_Match_Date__c', None),
             ('Founder_Recruitment_Not_A_Match_Note__c', None),
             ('Mentor_Recruitment_Status__c', None),
             ('Mentor_Recruitment_Potential_Date__c', None),
             ('Mentor_Recruitment_Potential_Note__c', None),
             ('Mentor_Recruitment_Will_Join_Date__c', None),
             ('Mentor_Recruitment_Will_Join_Note__c', None),
             ('Mentor_Recruitment_Join_Follow_Up_Date__c', None),
             ('Mentor_Recruitment_Join_Follow_Up_Note__c', None),
             ('Mentor_Recruitment_Join_Confirmed_Date__c', None),
             ('Mentor_Recruitment_Join_Confirmed_Note__c', None),
             ('Mentor_Recruitment_Not_A_Match_Date__c', None),
             ('Mentor_Recruitment_Not_A_Match_Note__c', None),
             ('Investor_Recruitment_Status__c', None),
             ('Investor_Recruitment_Potential_Date__c', None),
             ('Investor_Recruitment_Potential_Note__c', None),
             ('Investor_Recruitment_Will_Join_Date__c', None),
             ('Investor_Recruitment_Will_Join_Note__c', None),
             ('Investor_Recruitment_Join_Follow_Up_Date__c', None),
             ('Investor_Recruitment_Join_Follow_Up_Note__c', None),
             ('Investor_Recruitment_Join_Confirmed_Date__c', None),
             ('Investor_Recruitment_Join_Confirmed_Note__c', None),
             ('Investor_Recruitment_Not_A_Match_Date__c', None),
             ('Investor_Recruitment_Not_A_Match_Note__c', None),
             ('Mentee_1st_Status_Update_Date__c', None),
             ('Mentee_1st_Status_Update_Note__c', None),
             ('Mentee_2nd_Status_Update_Date__c', None),
             ('Mentee_2nd_Status_Update_Note__c', None),
             ('Average_Days_to_Match__c', None),
             ('Total_3_Mo_Surveys_Completed__c', None),
             ('Total_6_Mo_Surveys_Completed__c', None),
             ('Mentor_1st_Status_Update_Date__c', None),
             ('Mentor_1st_Status_Update_Note__c', None),
             ('Mentor_2nd_Status_Update_Date__c', None),
             ('Mentor_2nd_Status_Update_Note__c', None),
             ('Fundraiser_1st_Status_Update_Date__c', None),
             ('Fundraiser_1st_Status_Update_Note__c', None),
             ('Fundraiser_2nd_Status_Update_Date__c', None),
             ('Fundraiser_2nd_Status_Update_Note__c', None),
             ('Referral_Name__c', None),
             ('Investor_Business_URL__c', None),
             ('Investor_1st_Status_Update_Date__c', None),
             ('Investor_2nd_Status_Update_Date__c', None),
             ('Investor_1st_Status_Update_Note__c', None),
             ('Investor_2nd_Status_Update_Note__c', None),
             ('Investor_Mobile_Phone__c', None),
             ('Mentor_Paused_Until_Date__c', None),
             ('PB_Volunteer_Recruitment_Status__c', None),
             ('PB_Volunteer_Recruitment_Potential_Date__c', None),
             ('PB_Volunteer_Recruitment_Potential_Note__c', None),
             ('PB_Volunteer_Recruitment_Contact_Date__c', None),
             ('PB_Volunteer_Recruitment_FollowUp_Date__c', None),
             ('PB_Volunteer_Recruitment_Will_Join_Date__c', None),
             ('PB_Volunteer_Recruitment_Join_FU_Date__c', None),
             ('PB_Volunteer_Recruitment_Confirm_Date__c', None),
             ('PB_Volunteer_Recruit_Not_Interested_Date__c', None),
             ('Investor_Type_Institutional_Investor__c', False),
             ('Investor_Type_Angel_Investor__c', False),
             ('Total_As_Requestee_Pending_Acceptance__c', None),
             ('Total_As_Requestee_Accepted__c', None),
             ('Total_As_Requestor_Pending_Acceptance__c', None),
             ('Total_As_Requestor_Accepted__c', None),
             ('Lead_Volunteer_at_Events__c', False),
             ('Lead_Service_Provider_Volunteer__c', False),
             ('Lead_Bring_StartOut_to_my_City__c', False),
             ('Lead_Lesbian__c', False),
             ('Lead_Gay__c', False),
             ('Lead_Bisexual__c', False),
             ('Lead_Transgender__c', False),
             ('Lead_Queer__c', False),
             ('Lead_Ally__c', False),
             ('Lead_Identify_Other__c', False),
             ('Lead_Identify_Other_Description__c', None),
             ('Lead_Male__c', False),
             ('Lead_Female__c', False),
             ('Lead_Gender_Non_Conforming__c', False),
             ('Lead_African_American_Black__c', False),
             ('Lead_Asian__c', False),
             ('Lead_Hispanic_Latino__c', False),
             ('Lead_Native_American__c', False),
             ('Lead_Caucasian__c', False),
             ('Lead_Native_Hawaiian_Pacific_Islander__c', False),
             ('Lead_Ethnicity_Other__c', False),
             ('Lead_Ethnicity_Other_Description__c', None),
             ('Lead_Decline_to_Answer__c', False),
             ('Member_Company__c', None),
             ('Company_Logo_Link__c', None),
             ('Company_Annual_Revenue__c', None),
             ('Company_Website__c', None),
             ('Company_Number_of_Employees__c', None),
             ('Company_Stage_act__c', None),
             ('Rising_Atlanta__c', False),
             ('Rising_Denver__c', False),
             ('Rising_Seattle__c', False),
             ('Rising_Washington_DC__c', False),
             ('Specify_Giving_Back_Through_Volunteering__c', None),
             ('Racial_Ethnic_Identification__c', None),
             ('LGBTQ_Identification__c', None),
             ('Best_Describe_Role_in_Community__c', None),
             ('Contacted_About_Partnering_With_StartOut__c', None),
             ('Gender__c', None),
             ('Investor_Type__c', None),
             ('Seeking__c', None),
             ('Other_Identities__c', None),
             ('Giving_Member__c', False),
             ('Make_my_Profile_Searchable_on_NetworQ__c', False),
             ('Company_Other_Industries__c', None),
             ('Funding_Raised_act__c', False),
             ('Funding_Raised_Friends_Family_act__c', 0.0),
             ('Funding_Raised_Angel_act__c', 0.0),
             ('Funding_Raised_Seed_act__c', 0.0),
             ('Funding_Raised_Series_A_act__c', 0.0),
             ('Funding_Raised_Series_B_or_later_act__c', 0.0),
             ('Funding_Raised_Debt_Financing_act__c', 0.0),
             ('Investor_Company_Name_act__c', None),
             ('Investor_Company_Website__c', None),
             ('Investor_Company_Phone__c', None),
             ('Investor_Company_Address__c', None),
             ('Investor_Company_City__c', None),
             ('Investor_Company_State__c', None),
             ('Investor_Company_Zip_Code__c', None),
             ('Investor_Company_Country__c', None),
             ('Founder_App_Company_SF_ID__c', None),
             ('Registered_Free_Member__c', False),
             ('Date_Registered_Free_Member__c', None)]

# %%
for item in lst:
    print(item[0] + ', \\')
# Out:
# Id, \
# IsDeleted, \
# MasterRecordId, \
# AccountId, \
# LastName, \
# FirstName, \
# Salutation, \
# MiddleName, \
# Suffix, \
# Name, \
# OtherStreet, \
# OtherCity, \
# OtherState, \
# OtherPostalCode, \
# OtherCountry, \
# OtherLatitude, \
# OtherLongitude, \
# OtherGeocodeAccuracy, \
# OtherAddress, \
# MailingStreet, \
# MailingCity, \
# MailingState, \
# MailingPostalCode, \
# MailingCountry, \
# MailingLatitude, \
# MailingLongitude, \
# MailingGeocodeAccuracy, \
# MailingAddress, \
# Phone, \
# Fax, \
# MobilePhone, \
# HomePhone, \
# OtherPhone, \
# AssistantPhone, \
# ReportsToId, \
# Email, \
# Title, \
# Department, \
# AssistantName, \
# LeadSource, \
# Birthdate, \
# Description, \
# OwnerId, \
# HasOptedOutOfEmail, \
# HasOptedOutOfFax, \
# DoNotCall, \
# CreatedDate, \
# CreatedById, \
# LastModifiedDate, \
# LastModifiedById, \
# SystemModstamp, \
# LastActivityDate, \
# LastCURequestDate, \
# LastCUUpdateDate, \
# LastViewedDate, \
# LastReferencedDate, \
# ...
